# %% [markdown]
# <a href="https://colab.research.google.com/github/arushi-08/Neural-Machine-Translation/blob/master/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import unicodedata
import re
import math
import psutil
import time
import datetime
from io import open
import random
from random import shuffle
import argparse
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
import torch.cuda

"""this line clears sys to allow for argparse to work as gradient clipper"""
import sys; sys.argv=['']; del sys

# %%
use_cuda = torch.cuda.is_available()
print(use_cuda)
# Out:
# True

# %%
"""This function converts a Unicode string to plain ASCII from https://stackoverflow.com/a/518232/2809427"""
def uniToAscii(sentence):
    return ''.join(
        c for c in unicodedata.normalize('NFD', sentence)
        if unicodedata.category(c) != 'Mn'
    )


"""Lowercase, trim, and remove non-letter characters (from pytorch)"""
def normalizeString(s):
    s = re.sub(r" ##AT##-##AT## ", r" ", s)
    s = uniToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s   

def hindi_normalizeString(s):
  def hindi_processing(word):
      correct = ''
        # print(char)
      if ( u'\u0900' <= word <= u'\u097f') or word==" ":
        correct=correct+word
      return correct

  # with codecs.open('letter.tx', encoding='utf-8') as f:
 
  
  temp = ''
  s = s.replace('।', '')
  for i in s.split():
      correct = hindi_processing(i)
      temp = temp +' ' + correct
      temp = ' '.join(temp.split())
  return temp

  
"""Denote patterns that sentences must start with to be kept in dataset. 
Can be changed if desired (from pytorch)"""
eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re "
)



"""Filters each input-output pair, keeping sentences that are less than max_length 
if start_filter is true, also filters out sentences that don't start with eng_prefixes"""
def filterPair(p, max_length, start_filter):
    filtered = len(p[0].split(' ')) < max_length and \
        len(p[1].split(' ')) < max_length 
    if start_filter:
        return filtered and p[1].startswith(eng_prefixes)
    else:
        return filtered

"""Filters all of the input-output language pairs in the dataset using filterPair 
for each pair (from pytorch)"""
def filterPairs(pairs, max_length, start_filter):
    return [pair for pair in pairs if filterPair(pair, max_length, start_filter)]

# %%
"""start of sentence tag"""
SOS_token = 0

"""end of sentence tag"""
EOS_token = 1

"""unknown word tag (this is used to handle words that are not in our Vocabulary)"""
UNK_token = 2


"""Lang class, used to store the vocabulary of each language"""
class Lang:
    def __init__(self, language):
        self.language_name = language
        self.word_to_index = {"SOS":SOS_token, "EOS":EOS_token, "<UNK>":UNK_token}
        self.word_to_count = {}
        self.index_to_word = {SOS_token: "SOS", EOS_token: "EOS", UNK_token: "<UNK>"}
        self.vocab_size = 3
        self.cutoff_point = -1


    def countSentence(self, sentence):
        for word in sentence.split(' '):
            self.countWords(word)

    """counts the number of times each word appears in the dataset"""
    def countWords(self, word):
        if word not in self.word_to_count:
            self.word_to_count[word] = 1
        else:
            self.word_to_count[word] += 1

    """if the number of unique words in the dataset is larger than the
    specified max_vocab_size, creates a cutoff point that is used to
    leave infrequent words out of the vocabulary"""
    def createCutoff(self, max_vocab_size):
        word_freqs = list(self.word_to_count.values())
        word_freqs.sort(reverse=True)
        if len(word_freqs) > max_vocab_size:
            self.cutoff_point = word_freqs[max_vocab_size]

    """assigns each unique word in a sentence a unique index"""
    def addSentence(self, sentence):
        new_sentence = ''
        for word in sentence.split(' '):
            unk_word = self.addWord(word)
            if not new_sentence:
                new_sentence =unk_word
            else:
                new_sentence = new_sentence + ' ' + unk_word
        return new_sentence

    """assigns a word a unique index if not already in vocabulary
    and it appeaars often enough in the dataset
    (self.word_to_count is larger than self.cutoff_point)"""
    def addWord(self, word):
        if self.word_to_count[word] > self.cutoff_point:
            if word not in self.word_to_index:
                self.word_to_index[word] = self.vocab_size
                self.index_to_word[self.vocab_size] = word
                self.vocab_size += 1
            return word
        else:
            return self.index_to_word[2]

# %%
'''prepares both the input and output Lang classes from the passed dataset'''

def prepareLangs(lang1, lang2, file_path, reverse=False):
    print("Reading lines...")

    if len(file_path) == 2:
        lang1_lines = open(file_path[0], encoding='utf-8').read().strip().split('\n')
        
        lang2_lines = open(file_path[1], encoding='utf-8').read().strip().split('\n')

        if len(lang1_lines) != len(lang2_lines):
            print("Input and output text sizes do not align")
            print("Number of lang1 lines: %s " %len(lang1_lines))
            print("Number of lang2 lines: %s " %len(lang2_lines))
            quit()

        pairs = []

        for line in range(len(lang1_lines)):
          if lang1 == 'eng':
            pairs.append([normalizeString(lang1_lines[line]),
                          hindi_normalizeString(lang2_lines[line])])            
          else :
            pairs.append([hindi_normalizeString(lang1_lines[line]),
                          normalizeString(lang2_lines[line])]) 
           
            
    elif len(file_path) == 1:
        lines = open(file_path[0], encoding='utf-8').read().strip().split('\n')
        pairs = [[normalizeString(e[0]), hindi_normalizeString(e[1])] for e in l.split('\t') for l in lines]

    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %%
"""completely prepares both input and output languages 
and returns cleaned and trimmed train and test pairs"""

def prepareData(lang1, lang2, file_path, max_vocab_size=50000, 
                reverse=False, trim=0, start_filter=False, perc_train_set=0.9, 
                print_to=None):
    
    input_lang, output_lang, pairs = prepareLangs(lang1, lang2, 
                                                  file_path, reverse)
    
    print("Read %s sentence pairs" % len(pairs))
    
    if print_to:
        with open(print_to,'a') as f:
            f.write("Read %s sentence pairs \n" % len(pairs))
    
    if trim != 0:
        pairs = filterPairs(pairs, trim, start_filter)
        print("Trimmed to %s sentence pairs" % len(pairs))
        if print_to:
            with open(print_to,'a') as f:
                f.write("Read %s sentence pairs \n" % len(pairs))

    print("Counting words...")
    for pair in pairs:
        input_lang.countSentence(pair[0])
        output_lang.countSentence(pair[1])


    input_lang.createCutoff(max_vocab_size)
    output_lang.createCutoff(max_vocab_size)

    pairs = [(input_lang.addSentence(pair[0]),output_lang.addSentence(pair[1])) 
             for pair in pairs]

    shuffle(pairs)
    
    train_pairs = pairs[:math.ceil(perc_train_set*len(pairs))]
    test_pairs = pairs[math.ceil(perc_train_set*len(pairs)):]

    print("Train pairs: %s" % (len(train_pairs)))
    print("Test pairs: %s" % (len(test_pairs)))
    print("Counted Words -> Trimmed Vocabulary Sizes (w/ EOS and SOS tags):")
    print("%s, %s -> %s" % (input_lang.language_name, len(input_lang.word_to_count),
                            input_lang.vocab_size,))
    print("%s, %s -> %s" % (output_lang.language_name, len(output_lang.word_to_count), 
                            output_lang.vocab_size))
    print()

    if print_to:
        with open(print_to,'a') as f:
            f.write("Train pairs: %s" % (len(train_pairs)))
            f.write("Test pairs: %s" % (len(test_pairs)))
            f.write("Counted Words -> Trimmed Vocabulary Sizes (w/ EOS and SOS tags):")
            f.write("%s, %s -> %s" % (input_lang.language_name, 
                                      len(input_lang.word_to_count),
                                      input_lang.vocab_size,))
            f.write("%s, %s -> %s \n" % (output_lang.language_name, len(output_lang.word_to_count), 
                            output_lang.vocab_size))
        
    return input_lang, output_lang, train_pairs, test_pairs

# %%
"""converts a sentence to one hot encoding vectors - pytorch allows us to just
use the number corresponding to the unique index for that word,
rather than a complete one hot encoding vector for each word"""
def indexesFromSentence(lang, sentence):
    indexes = []
    for word in sentence.split(' '):
        try:
            indexes.append(lang.word_to_index[word])
        except:
            indexes.append(lang.word_to_index["<UNK>"])
    return indexes


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    result = torch.LongTensor(indexes).view(-1)
    if use_cuda:
        return result.cuda()
    else:
        return result
      
"""converts a pair of sentence (input and target) to a pair of tensors"""
def tensorsFromPair(input_lang, output_lang, pair):
    input_variable = tensorFromSentence(input_lang, pair[0])
    target_variable = tensorFromSentence(output_lang, pair[1])
    return (input_variable, target_variable)
  

"""converts from tensor of one hot encoding vector indices to sentence"""
def sentenceFromTensor(lang, tensor):
    raw = tensor.data
    words = []
    for num in raw:
        words.append(lang.index_to_word[num.item()])
    return ' '.join(words)

# %%
"""seperates data into batches of size batch_size"""
def batchify(data, input_lang, output_lang, batch_size, shuffle_data=True):
    if shuffle_data == True:
        shuffle(data)
    number_of_batches = len(data) // batch_size
    batches = list(range(number_of_batches))
    longest_elements = list(range(number_of_batches))
    
    for batch_number in range(number_of_batches):
        longest_input = 0
        longest_target = 0
        input_variables = list(range(batch_size))
        target_variables = list(range(batch_size))
        index = 0      
        for pair in range((batch_number*batch_size),((batch_number+1)*batch_size)):
            input_variables[index], target_variables[index] = tensorsFromPair(input_lang, output_lang, data[pair])
            if len(input_variables[index]) >= longest_input:
                longest_input = len(input_variables[index])
            if len(target_variables[index]) >= longest_target:
                longest_target = len(target_variables[index])
            index += 1
        batches[batch_number] = (input_variables, target_variables)
        longest_elements[batch_number] = (longest_input, longest_target)
    return batches , longest_elements, number_of_batches


"""pads batches to allow for sentences of variable lengths to be computed in parallel"""
def pad_batch(batch):
    padded_inputs = torch.nn.utils.rnn.pad_sequence(batch[0],padding_value=EOS_token)
    padded_targets = torch.nn.utils.rnn.pad_sequence(batch[1],padding_value=EOS_token)
    return (padded_inputs, padded_targets)

# %%
class EncoderRNN(nn.Module):
	def __init__(self,input_size,hidden_size,layers=1,dropout=0.1,
               bidirectional=True):
		super(EncoderRNN, self).__init__()

		if bidirectional:
			self.directions = 2
		else:
			self.directions = 1
		self.input_size = input_size
		self.hidden_size = hidden_size
		self.num_layers = layers
		self.dropout = dropout
		self.embedder = nn.Embedding(input_size,hidden_size)
		self.dropout = nn.Dropout(dropout)
		self.lstm = nn.LSTM(input_size=hidden_size,hidden_size=hidden_size,
                        num_layers=layers,dropout=dropout,
                        bidirectional=bidirectional,batch_first=False)
		self.fc = nn.Linear(hidden_size*self.directions, hidden_size)

	def forward(self, input_data, h_hidden, c_hidden):
		embedded_data = self.embedder(input_data)
		embedded_data = self.dropout(embedded_data)
		hiddens, outputs = self.lstm(embedded_data, (h_hidden, c_hidden))

		return hiddens, outputs

	"""creates initial hidden states for encoder corresponding to batch size"""
	def create_init_hiddens(self, batch_size):
		h_hidden = Variable(torch.zeros(self.num_layers*self.directions, 
                                    batch_size, self.hidden_size))
		c_hidden = Variable(torch.zeros(self.num_layers*self.directions, 
                                    batch_size, self.hidden_size))
		if torch.cuda.is_available():
			return h_hidden.cuda(), c_hidden.cuda()
		else:
			return h_hidden, c_hidden

# %%
class DecoderAttn(nn.Module):
	def __init__(self, hidden_size, output_size, layers=1, dropout=0.1, bidirectional=True):
		super(DecoderAttn, self).__init__()

		if bidirectional:
			self.directions = 2
		else:
			self.directions = 1
		self.output_size = output_size
		self.hidden_size = hidden_size
		self.num_layers = layers
		self.dropout = dropout
		self.embedder = nn.Embedding(output_size,hidden_size)
		self.dropout = nn.Dropout(dropout)
		self.score_learner = nn.Linear(hidden_size*self.directions, 
                                   hidden_size*self.directions)
		self.lstm = nn.LSTM(input_size=hidden_size,hidden_size=hidden_size,
                        num_layers=layers,dropout=dropout,
                        bidirectional=bidirectional,batch_first=False)
		self.context_combiner = nn.Linear((hidden_size*self.directions)
                                      +(hidden_size*self.directions), hidden_size)
		self.tanh = nn.Tanh()
		self.output = nn.Linear(hidden_size, output_size)
		self.soft = nn.Softmax(dim=1)
		self.log_soft = nn.LogSoftmax(dim=1)


	def forward(self, input_data, h_hidden, c_hidden, encoder_hiddens):

		embedded_data = self.embedder(input_data)
		embedded_data = self.dropout(embedded_data)	
		batch_size = embedded_data.shape[1]
		hiddens, outputs = self.lstm(embedded_data, (h_hidden, c_hidden))	
		top_hidden = outputs[0].view(self.num_layers,self.directions,
                                 hiddens.shape[1],
                                 self.hidden_size)[self.num_layers-1]
		top_hidden = top_hidden.permute(1,2,0).contiguous().view(batch_size,-1, 1)

		prep_scores = self.score_learner(encoder_hiddens.permute(1,0,2))
		scores = torch.bmm(prep_scores, top_hidden)
		attn_scores = self.soft(scores)
		con_mat = torch.bmm(encoder_hiddens.permute(1,2,0),attn_scores)
		h_tilde = self.tanh(self.context_combiner(torch.cat((con_mat,
                                                         top_hidden),dim=1)
                                              .view(batch_size,-1)))
		pred = self.output(h_tilde)
		pred = self.log_soft(pred)

		
		return pred, outputs

# %%
'''Performs training on a single batch of training data. Computing the loss 
according to the passed loss_criterion and back-propagating on this loss.'''

def train_batch(input_batch, target_batch, encoder, decoder, 
                encoder_optimizer, decoder_optimizer, loss_criterion):
	encoder_optimizer.zero_grad()
	decoder_optimizer.zero_grad()
	loss = 0
	enc_h_hidden, enc_c_hidden = encoder.create_init_hiddens(input_batch.shape[1])

	enc_hiddens, enc_outputs = encoder(input_batch, enc_h_hidden, enc_c_hidden)

	decoder_input = Variable(torch.LongTensor(1,input_batch.shape[1]).
                           fill_(output_lang.word_to_index.get("SOS")).cuda()) if use_cuda \
					else Variable(torch.LongTensor(1,input_batch.shape[1]).
                        fill_(output_lang.word_to_index.get("SOS")))

	dec_h_hidden = enc_outputs[0]
	dec_c_hidden = enc_outputs[1]
	
	for i in range(target_batch.shape[0]):
		pred, dec_outputs = decoder(decoder_input, dec_h_hidden, 
                                dec_c_hidden, enc_hiddens)

		decoder_input = target_batch[i].view(1,-1)
		dec_h_hidden = dec_outputs[0]
		dec_c_hidden = dec_outputs[1]
		
		loss += loss_criterion(pred,target_batch[i])


	loss.backward()

	torch.nn.utils.clip_grad_norm_(encoder.parameters(),args.clip)
	torch.nn.utils.clip_grad_norm_(decoder.parameters(),args.clip)

	encoder_optimizer.step()
	decoder_optimizer.step()

	return loss.item() / target_batch.shape[0]

# %%
'''Performs a complete epoch of training through all of the training_batches'''

def train(train_batches, encoder, decoder, encoder_optimizer, decoder_optimizer, loss_criterion):

	round_loss = 0
	i = 1
	for batch in train_batches:
		i += 1
		(input_batch, target_batch) = pad_batch(batch)
		batch_loss = train_batch(input_batch, target_batch, encoder, decoder, encoder_optimizer, decoder_optimizer, loss_criterion)
		round_loss += batch_loss

	return round_loss / len(train_batches)

# %%
'''Evaluates the loss on a single batch of test data. Computing the loss 
according to the passed loss_criterion. Does not perform back-prop'''

def test_batch(input_batch, target_batch, encoder, decoder, loss_criterion):
	
	loss = 0

	#create initial hidde state for encoder
	enc_h_hidden, enc_c_hidden = encoder.create_init_hiddens(input_batch.shape[1])

	enc_hiddens, enc_outputs = encoder(input_batch, enc_h_hidden, enc_c_hidden)

	decoder_input = Variable(torch.LongTensor(1,input_batch.shape[1]).
                           fill_(output_lang.word_to_index.get("SOS")).cuda()) if use_cuda \
					else Variable(torch.LongTensor(1,input_batch.shape[1]).
                        fill_(output_lang.word_to_index.get("SOS")))
	dec_h_hidden = enc_outputs[0]
	dec_c_hidden = enc_outputs[1]
	
	for i in range(target_batch.shape[0]):
		pred, dec_outputs = decoder(decoder_input, dec_h_hidden, dec_c_hidden, enc_hiddens)

		topv, topi = pred.topk(1,dim=1)
		ni = topi.view(1,-1)
		
		decoder_input = ni
		dec_h_hidden = dec_outputs[0]
		dec_c_hidden = dec_outputs[1]

		loss += loss_criterion(pred,target_batch[i])
		
	return loss.item() / target_batch.shape[0]

# %%
'''Computes the loss value over all of the test_batches'''

def test(test_batches, encoder, decoder, loss_criterion):

	with torch.no_grad():
		test_loss = 0

		for batch in test_batches:
			(input_batch, target_batch) = pad_batch(batch)
			batch_loss = test_batch(input_batch, target_batch, encoder, decoder, loss_criterion)
			test_loss += batch_loss

	return test_loss / len(test_batches)

# %%
'''Returns the predicted translation of a given input sentence. Predicted
translation is trimmed to length of cutoff_length argument'''

def evaluate(encoder, decoder, sentence, cutoff_length):
	with torch.no_grad():
		input_variable = tensorFromSentence(input_lang, sentence)
		input_variable = input_variable.view(-1,1)
		enc_h_hidden, enc_c_hidden = encoder.create_init_hiddens(1)

		enc_hiddens, enc_outputs = encoder(input_variable, enc_h_hidden, enc_c_hidden)

		decoder_input = Variable(torch.LongTensor(1,1).fill_(output_lang.word_to_index.get("SOS")).cuda()) if use_cuda \
						else Variable(torch.LongTensor(1,1).fill_(output_lang.word_to_index.get("SOS")))
		dec_h_hidden = enc_outputs[0]
		dec_c_hidden = enc_outputs[1]

		decoded_words = []

		for di in range(cutoff_length):
			pred, dec_outputs = decoder(decoder_input, dec_h_hidden, dec_c_hidden, enc_hiddens)

			topv, topi = pred.topk(1,dim=1)
			ni = topi.item()
			if ni == output_lang.word_to_index.get("EOS"):
				decoded_words.append('<EOS>')
				break
			else:
				decoded_words.append(output_lang.index_to_word[ni])

			decoder_input = Variable(torch.LongTensor(1,1).fill_(ni).cuda()) if use_cuda \
							else Variable(torch.LongTensor(1,1).fill_(ni))
			dec_h_hidden = dec_outputs[0]
			dec_c_hidden = dec_outputs[1]

		output_sentence = ' '.join(decoded_words)
    
		return output_sentence

# %%
'''Evaluates prediction translations for a specified number (n) of sentences
chosen randomly from a list of passed sentence pairs. Returns three sentences
in the format:
                  > input sentence
                  = correct translation
                  < predicted translation'''

def evaluate_randomly(encoder, decoder, pairs, n=2, trim=100):
	for i in range(n):
		pair = random.choice(pairs)
		print('>', pair[0])
		print('=', pair[1])
		output_sentence = evaluate(encoder, decoder, pair[0],cutoff_length=trim)
		print('<', output_sentence)
		print('')    
		if create_txt:
			f = open(print_to, 'a')
			f.write("\n \
				> %s \n \
				= %s \n \
				< %s \n" % (pair[0], pair[1], output_sentence))
			f.close()

# %%
'''Used to plot the progress of training. Plots the loss value vs. time'''
def showPlot(times, losses, fig_name):
    x_axis_label = 'Minutes'
    colors = ('red','blue')
    if max(times) >= 120:
    	times = [mins/60 for mins in times]
    	x_axis_label = 'Hours'
    i = 0
    for key, losses in losses.items():
    	if len(losses) > 0:
    		plt.plot(times, losses, label=key, color=colors[i])
    		i += 1
    plt.legend(loc='upper left')
    plt.xlabel(x_axis_label)
    plt.ylabel('Loss')
    plt.title('Training Results')
    plt.savefig(fig_name+'.png')
    plt.close('all')
    
'''prints the current memory consumption'''
def mem():
	if use_cuda:
		mem = torch.cuda.memory_allocated()/1e7
	else:
		mem = psutil.cpu_percent()
	print('Current mem usage:')
	print(mem)
	return "Current mem usage: %s \n" % (mem)

'''converts a time measurement in seconds to hours'''
def asHours(s):
	m = math.floor(s / 60)
	h = math.floor(m / 60)
	s -= m * 60
	m -= h * 60
	return '%dh %dm %ds' % (h, m, s)

# %%
'''The master function that trains the model. Evlautes progress on the train set
(if present) and also records the progress of training in both a txt file and
a png graph. Also can save the weights of both the Encoder and Decoder 
for future use.'''

def train_and_test(epochs, test_eval_every, plot_every, learning_rate, 
                   lr_schedule, train_pairs, test_pairs, input_lang, 
                   output_lang, batch_size, test_batch_size, encoder, decoder, 
                   loss_criterion, trim, save_weights):
	
	times = []
	losses = {'train set':[], 'test set': []}

	test_batches, longest_seq, n_o_b = batchify(test_pairs, input_lang, 
                                              output_lang, test_batch_size, 
                                              shuffle_data=False)

	start = time.time()
	for i in range(1,epochs+1):
    
		'''adjust the learning rate according to the learning rate schedule
		specified in lr_schedule'''
		if i in lr_schedule.keys():
			learning_rate /= lr_schedule.get(i)


		encoder.train()
		decoder.train()

		encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
		decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)

		batches, longest_seq, n_o_b = batchify(train_pairs, input_lang, 
                                           output_lang, batch_size, 
                                           shuffle_data=True)
		train_loss = train(batches, encoder, decoder, encoder_optimizer, 
                       decoder_optimizer, loss_criterion)
		
		now = time.time()
		print("Iter: %s \nLearning Rate: %s \nTime: %s \nTrain Loss: %s \n" 
          % (i, learning_rate, asHours(now-start), train_loss))

		if create_txt:
			with open(print_to, 'a') as f:
				f.write("Iter: %s \nLeaning Rate: %s \nTime: %s \nTrain Loss: %s \n" \
					% (i, learning_rate, asHours(now-start), train_loss))

		if i % test_eval_every == 0:
			if test_pairs:
				test_loss = test(test_batches, encoder, decoder, criterion)
				print("Test set loss: %s" % (test_loss))
				if create_txt:
					with open(print_to, 'a') as f:
						f.write("Test Loss: %s \n" % (test_loss))
				evaluate_randomly(encoder, decoder, test_pairs, trim)
			else:
				evaluate_randomly(encoder, decoder, train_pairs, trim)

		if i % plot_every == 0:
			times.append((time.time()-start)/60)
			losses['train set'].append(train_loss)
			if test_pairs:
				losses['test set'].append(test_loss)
			showPlot(times, losses, output_file_name)
			if save_weights:
				torch.save(encoder.state_dict(), output_file_name+'_enc_weights.pt')
				torch.save(decoder.state_dict(), output_file_name+'_dec_weights.pt')

# %%
from google.colab import files
uploaded = files.upload()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Language-Translation-datasets/IITBombay/prunedCorpus
# Out:
# /content/drive/My Drive/Language-Translation-datasets/IITBombay/prunedCorpus

# %%
ls
# Out:
# eng-hin.txt
# geometric_embedding/
# hindi-tokenizer/
# pruned_train.en
# pruned_train.hi
# testdata.orig_trim.10_vocab.20000_directions.2_layers.2_hidden.440_dropout.0.2_learningrate.1_batch.32_epochs.100.png
# testdata.orig_trim.10_vocab.20000_directions.2_layers.2_hidden.440_dropout.0.2_learningrate.1_batch.32_epochs.100.txt

# %%
with open( 'pruned_train.hi', 'r') as handle:
  data = handle.read()
  hindi_data = data.split('\n')

# %%
with open( 'pruned_train.en', 'r') as handle:
  data = handle.read()
  eng_data = data.split('\n')

# %%
with open('eng-hin.txt', 'w') as f:
  for l in zip(eng_data,hindi_data):
    f.write(l[0] + "\t" + l[1] + "\n")

# %%
with open('eng-hin.txt', 'r') as f:
  d = f.read()
  d = d.split('\n')

# %%
d

# %%
pwd
# Out:
# '/content'

# %%
ls

# %%
"""PROVIDE INFORMATION ON THE DATASET AND DATASET CLEANING"""

input_lang_name = 'eng'
output_lang_name = 'hin'

"""name of your dataset"""
dataset = 'orig'

"""file path of dataset in the form of a tuple. If translated sentences are
stored in two files, this tuple will have two elements"""
raw_data_file_path = ('pruned_train.en','pruned_train.hi')

"""True if you want to reverse the order of the sentence pairs. For example, 
in our dataset the sentence pairs list the English sentence first followed by
the French translation. But we want to translate from French to English,
so we set reverse as True."""
reverse=False

"""Remove sentences from dataset that are longer than trim (in either language)"""
trim = 10

"""max number of words in the vocabulary for both languages"""
max_vocab_size= 20000

"""if true removes sentences from the dataset that don't start with eng_prefixes.
Typically will want to use False, but implemented to compare results with Pytorch
tutorial. Can also change the eng_prefixes to prefixes of other languages or
other English prefixes. Just be sure that the prefixes apply to the OUTPUT
language (i.e. the language that the model is translating to NOT from)"""
start_filter = False

"""denotes what percentage of the data to use as training data. the remaining 
percentage becomes test data. Typically want to use 0.8-0.9. 1.0 used here to 
compare with PyTorch results where no test set was utilized"""
perc_train_set = 1.0

# %%
"""OUTPUT OPTIONS"""

"""denotes how often to evaluate a loss on the test set and print
sample predictions on the test set.
if no test set, simply prints sample predictions on the train set."""
test_eval_every = 1

"""denotes how often to plot the loss values of train and test (if applicable)"""
plot_every = 1

"""if true creates a txt file of the output"""
create_txt = True

"""if true saves the encoder and decoder weights to seperate .pt files for later use"""
save_weights = False

# %%
"""HYPERPARAMETERS: FEEL FREE TO PLAY WITH THESE TO TRY TO ACHIEVE BETTER RESULTS"""

"""signifies whether the Encoder and Decoder should be bidirectional LSTMs or not"""
bidirectional = True
if bidirectional:
	directions = 2
else:
	directions = 1

"""number of layers in both the Encoder and Decoder"""
layers = 2

"""Hidden size of the Encoder and Decoder"""
hidden_size = 440

"""Dropout value for Encoder and Decoder"""
dropout = 0.2

"""Training set batch size"""
batch_size = 32

"""Test set batch size"""
test_batch_size = 32

"""number of epochs (full passes through the training data)"""
epochs = 100

"""Initial learning rate"""
learning_rate= 1

"""Learning rate schedule. Signifies by what factor to divide the learning rate
at a certain epoch. For example {5:10} would divide the learning rate by 10
before the 5th epoch and {5:10, 10:100} would divide the learning rate by 10
before the 5th epoch and then again by 100 before the 10th epoch"""
lr_schedule = {}

"""loss criterion, see https://pytorch.org/docs/stable/nn.html for other options"""
criterion = nn.NLLLoss()

# %%
"""******************************************************************
********************NO NEED TO ALTER ANYTHING BELOW******************
******************************************************************"""

use_cuda = torch.cuda.is_available()


"""for plotting of the loss"""
plt.switch_backend('agg')

output_file_name = "testdata.%s_trim.%s_vocab.%s_directions.%s_layers.%s_hidden.%s_dropout.%s_learningrate.%s_batch.%s_epochs.%s" % (dataset,trim,max_vocab_size,directions,layers,hidden_size,dropout,learning_rate,batch_size,epochs)

if create_txt:
	print_to = output_file_name+'.txt'
	with open(print_to, 'w+') as f:
		f.write("Starting Training \n")
else:
	print_to = None

input_lang, output_lang, train_pairs, test_pairs = prepareData(
    input_lang_name, output_lang_name, raw_data_file_path, 
    max_vocab_size=max_vocab_size, reverse=reverse, trim=trim, 
    start_filter=start_filter, perc_train_set=perc_train_set, print_to=print_to)

print('Train Pairs #')
print(len(train_pairs))


"""for gradient clipping from https://github.com/pytorch/examples/blob/master/word_language_model/main.py"""

parser = argparse.ArgumentParser(description='PyTorch Wikitext-2 RNN/LSTM Language Model')
parser.add_argument('--clip', type=float, default=0.25,
                    help='gradient clipping')
args = parser.parse_args()

mem()

if create_txt:
	with open(print_to, 'a') as f:
		f.write("\nRandom Train Pair: %s \n\nRandom Test Pair: %s \n\n" 
            % (random.choice(train_pairs),random.choice(test_pairs) 
               if test_pairs else "None"))
		f.write(mem())


"""create the Encoder"""
encoder = EncoderRNN(input_lang.vocab_size, hidden_size, layers=layers, 
                     dropout=dropout, bidirectional=bidirectional)

"""create the Decoder"""
decoder = DecoderAttn(hidden_size, output_lang.vocab_size, layers=layers, 
                      dropout=dropout, bidirectional=bidirectional)

print('Encoder and Decoder Created')
mem()

if use_cuda:
	print('Cuda being used')
	encoder = encoder.cuda()
	decoder = decoder.cuda()

print('Number of epochs: '+str(epochs))

if create_txt:
	with open(print_to, 'a') as f:
		f.write('Encoder and Decoder Created\n')
		f.write(mem())
		f.write("Number of epochs %s \n" % (epochs))

train_and_test(epochs, test_eval_every, plot_every, learning_rate, lr_schedule, 
                                                           train_pairs, test_pairs, input_lang, output_lang, batch_size, 
               test_batch_size, encoder, decoder, criterion, trim, save_weights)
# Out:
# Reading lines...
# Read 788098 sentence pairs
# Trimmed to 174488 sentence pairs
# Counting words...
# Train pairs: 174488
# Test pairs: 0
# Counted Words -> Trimmed Vocabulary Sizes (w/ EOS and SOS tags):
# eng, 39160 -> 17654
# hin, 51737 -> 15583
#
# Train Pairs #
# 174488
# Current mem usage:
# 0.0
# Current mem usage:
# 0.0
# Encoder and Decoder Created
# Current mem usage:
# 0.0
# Cuda being used
# Number of epochs: 100
# Current mem usage:
# 15.7038592
# Iter: 1
# Learning Rate: 1
# Time: 0h 4m 4s
# Train Loss: 3.7560127095778713
#
# > list of airports by iata code l
# = विमानक्षेत्रों की सूची कोड अनुसारः
# < विमानक्षेत्रों की सूची कोड कोड <EOS>
#
# > authority that has been delegated .
# = ऐसा प्राधिकार जो सौंपा गया है
# < जो <UNK> को <UNK> किया गया है <EOS>
#
# > lying in between two things .
# = जो दो बिन्दुओं के मध्य स्थित हो
# < जो <UNK> में <UNK> में <EOS>
#
# > show form ui code
# = यूआई कोड से दिखाएँ
# < विंडो के बीच विंडो दिखाएँ <EOS>
#
# > do not speak chat room name .
# = चैट रूम नाम के बारे में मत बोलें
# < <UNK> नाम नाम नहीं <EOS>
#
# > google talk work name
# = गूगल टाक कार्य नाम
# < नया नाम नाम नाम <EOS>
#
# > customize current view
# = मनपसंद मौज़ूदा दृश्य
# < चयनित दृश्य को <UNK> दिखाएँ <EOS>
#
# > xml description of the user interface
# = प्रयोक्ता अतरफलक का एक्सएमएल वर्णन
# < ऑडियो के <UNK> के लिए <UNK> <EOS>
#
# > to study birds in their natural surroundings .
# = पक्षियों के प्राकृतिक परिवेश में पक्षियों का अध्ययन करना
# < जो <UNK> में <UNK> से संबंधित <EOS>
#
# > jaya bharata jananiya tanujate
# = जय भारत <UNK> <UNK>
# < <UNK> <UNK> <UNK> <UNK> <UNK> <EOS>
#
# Iter: 2
# Learning Rate: 1
# Time: 0h 8m 11s
# Train Loss: 2.9950645676576206
#
# > extract the selected archive
# = चयनित अभिलेख में निकालें
# < चयनित अभिलेख अभिलेख में निकालें <EOS>
#
# > fade trails to background color
# = पुछल्लों को पृष्ठ भूमि रंग में विलीन करें
# < रंग रंग के लिए <UNK> <UNK> <EOS>
#
# > the difference was only in respect of style .
# = अन्तर केवल शैली का था
# < <UNK> <UNK> में <UNK> का <UNK> था <EOS>
#
# > harishchandra <UNK> was a new type of journal .
# = हरिश्चन्द्र <UNK> एक नये प्रकार की पत्रिका थी
# < <UNK> <UNK> के नया नया प्रकार था <EOS>
#
# > justice was provided to the common man .
# = उसके राज्य में आम आदमी को न्याय मिला
# < <UNK> <UNK> <UNK> के लिए <UNK> था <EOS>
#
# > national highway
# = राष्ट्रीय राजमार्ग <UNK>
# < राष्ट्रीय राष्ट्रीय <UNK> <EOS>
#
# > los angeles lakers
# = लॉस एंजेल्स <UNK>
# < <UNK> <UNK> <UNK> <UNK> <EOS>
#
# > kal ho naa ho
# = कल हो ना हो
# < जो <UNK> की <UNK> हो <EOS>
#
# > his wife comes from california .
# = इनकी पत्नी कैलिफ़ोर्निया से हैं
# < उसकी <UNK> से <UNK> से <UNK> है <EOS>
#
# > edit properties of this account
# = इस खाते के गुणों को संपादित करें
# < इस आकार के गुण का उपयोग करें <EOS>
#
# Iter: 3
# Learning Rate: 1
# Time: 0h 12m 16s
# Train Loss: 2.5889208538914965
#
# > international trade is vital for healthy economies .
# = अंतर्राष्ट्रीय व्यापार मज़बूत अर्थव्यवस्था के लिए आवश्यक है
# < <UNK> व्यापार <UNK> <UNK> के लिए <UNK> है <EOS>
#
# > on <UNK> and larger machines use the special mounting
# = और बड़ी मशीनों पर विशेष बढ़ते उपयोग करें
# < <UNK> और <UNK> <UNK> में <UNK> का उपयोग करें <EOS>
#
# > thread priority setting is ignored .
# = थ्रेड वरीयता समायोजना पर ध्यान नहीं दिया गया
# < <UNK> <UNK> <UNK> <UNK> <UNK> है <EOS>
#
# > these volunteers are really <UNK> and brave !
# = ये स्वयंसेवक भी कितने <UNK> और साहसी हैं
# < ये <UNK> <UNK> और <UNK> <UNK> हैं <EOS>
#
# > and created you in pairs
# = और हमने तुम लोगों को जोड़ा जोड़ा पैदा किया
# < और तुम तुम लोगों में तुम से हो <EOS>
#
# > it policy
# = सूचना प्रौद्योगिकी नीति
# < और <UNK> नीति <EOS>
#
# > vala source file
# = वाला स्रोत फ़ाइल
# < फ़ाइल स्रोत फ़ाइल <EOS>
#
# > <UNK> gathered sticks to make the <UNK> .
# = कनु <UNK> <UNK> लाया
# < <UNK> <UNK> <UNK> को <UNK> <UNK> <EOS>
#
# > we know how to fix hunger .
# = हम भूख का इलाज जानते हैं
# < हम हम <UNK> <UNK> चाहते हैं <EOS>
#
# > frequency <UNK> spread spectrum
# = आवृत्ति <UNK> प्रसार स्पेक्ट्रम
# < <UNK> <UNK> <UNK> <UNK> <UNK> <EOS>
#
# Iter: 4
# Learning Rate: 1
# Time: 0h 16m 21s
# Train Loss: 2.3243430794757636
#
# > skype home name
# = स्काइप होम नाम
# < स्काइप होम नाम नाम <EOS>
#
# > document contains no annotations
# = यह दस्तावेज़ कोई एनोटेशन समाहित नहीं करता है
# < दस्तावेज़ कोई <UNK> या <UNK> नहीं है <EOS>
#
# > hide a numeric label
# = न्यूमेरिक लेबल छुपाएँ
# < <UNK> लेबल लेबल छुपाएँ <EOS>
#
# > in which people develop their own solutions
# = जिसमें लोग अपने विकास के लिए स्वयं समाधान करे
# < जो लोग अपनी नमाज़ के साथ <UNK> <EOS>
#
# > change the music volume
# = संगीत की आवाज़ बदलें
# < संगीत के लिए संगीत को बदलें <EOS>
#
# > native to a land or region .
# = एक क्षेत्र या भूमि का निवासी
# < एक भूमि या क्षेत्र में <UNK> <EOS>
#
# > punjab state co operative milk producers federation limited
# = पंजाब राज्य सहकारी दुग्ध उत्पादक संघ मर्यादित
# < राज्य राज्य सहकारी सहकारी सहकारी लिमिटेड <EOS>
#
# > syntax error not enough arguments
# = सिंटेक्स त्रुटिः पर्याप्त आर्गुमेंट नहीं
# < <UNK> त्रुटि पर्याप्त पर्याप्त पर्याप्त नहीं है <EOS>
#
# > extended binary coded decimal interchange code
# = विस्तारित द्वि आधारी कोडित <UNK> प्रतिस्थापन कोड
# < <UNK> <UNK> <UNK> <UNK> <UNK> कोड <EOS>
#
# > choose sort order for pick items mode
# = आइटम चुनने के मोड का क्रम बद्ध चुनिए
# < कोई मद के लिए <UNK> के लिए <UNK> <EOS>
#
# Iter: 5
# Learning Rate: 1
# Time: 0h 20m 28s
# Train Loss: 2.133154950775901
#
# > heritage village for parents of nrk s
# = अनिवासी केरलवासियों के माता पिता के लिए विरासत ग्राम
# < <UNK> के लिए <UNK> <UNK> <UNK> <EOS>
#
# > show contact preview below the contact list
# = संपर्क सूची के नीचे संपर्क पूर्वावलोकन दिखाता है
# < संपर्क सूची के नीचे संपर्क पूर्वावलोकन दिखाता है <EOS>
#
# > this too should be prevented in india .
# = भारत को ऐसी स्थिति से भी बचाना चाहिए था
# < यह भी भारत में <UNK> की जानी चाहिए <EOS>
#
# > disable keyboard layouts
# = कुंजीपट ख़ाका सक्षम करें
# < कुंजीपट क्षैतिज को अक्षम करें <EOS>
#
# > the main gnome menu
# = मुख्य गनोम मेनू
# < मुख्य गनोम मेन्यू फ़ोल्डर <EOS>
#
# > i felt vaguely sorry for it .
# = मुझे उसके लिए बेहद अफसोस हो रहा था
# < मैं उसे <UNK> के लिए <UNK> <UNK> था <EOS>
#
# > her fixed marriage is an open secret now .
# = उसका निश्चित विवाह अब एक खुला रहस्य है
# < उसकी <UNK> <UNK> एक नया नया <UNK> है <EOS>
#
# > no chiasmus backend configured
# = कोई चियास्मस बैकएण्ड कॉन्फ़िगर नहीं
# < कोई बैकेंड बैकेंड नहीं <EOS>
#
# > he is a true living legend .
# = वह एक सच्ची जीवंत विभूति हैं
# < वह एक <UNK> <UNK> है <EOS>
#
# > live <UNK> in these little tin <UNK>
# = टीन के <UNK> जैसे घरों में <UNK> रहते है
# < इन में <UNK> <UNK> <UNK> <UNK> में <UNK> है <EOS>
#
# Iter: 6
# Learning Rate: 1
# Time: 0h 24m 37s
# Train Loss: 1.981814278724523
#
# > delete all but the last
# = सभी मिटाएँ सिवाय अंतिम के
# < सभी उत्तर को अंतिम जवाब दें <EOS>
#
# > an empty tableau slot
# = एक खाली तस्वीर खाँचा
# < खाली तस्वीर खाँचा पर एक खाली खाँचा <EOS>
#
# > open selected files with an application
# = चयनित फ़ाइलें एक प्रोग्राम के साथ खोलें
# < चयनित फ़ाइलें एक अनुप्रयोग के साथ खोलें <EOS>
#
# > all information will be kept strictly confidential .
# = सभी सूचनाओं को <UNK> से गोपनीय रखा जायेगा
# < सभी सूचना <UNK> को <UNK> दिया जाएगा <EOS>
#
# > the cost rates are rising continuously .
# = लागत दर में लगातार वृद्धि हो रही है
# < लागत की लागत पर <UNK> हैं <EOS>
#
# > i know the <UNK> they suffered .
# = मैं उनके <UNK> को अच्छी तरह जानता हूं
# < मैं <UNK> <UNK> को भी नहीं हूं <EOS>
#
# > minimum balance in the account
# = खाते में न्यूनतम शेष
# < खाता में न्यूनतम शेष शेष <EOS>
#
# > move selected codec priority downwards
# = चयनित कोडेक प्राथमिकता को नीचे की ओर खिसकाएँ
# < चयनित जवाब को नए प्राथमिकता में खिसकाएँ <EOS>
#
# > constitution laid down annual audit report before parliament
# = संसद के समक्ष वार्षिक लेखा परीक्षा रिपोर्ट रखी गई
# < संविधान के नीचे वार्षिक वार्षिक रिपोर्ट <UNK> रिपोर्ट <EOS>
#
# > upgrade the package at
# = पैकेज यहाँ पर उन्नत बनाएँ
# < पैकेज पर पैकेज अद्यतन करें <EOS>
#
# Iter: 7
# Learning Rate: 1
# Time: 0h 28m 45s
# Train Loss: 1.8567461065221063
#
# > raw files are g d
# = रॉ फ़ाइलें हैं <UNK>
# < <UNK> फ़ाइलें <UNK> हैं <EOS>
#
# > compose a new mail message
# = नया डाक संदेश लिखेंNew
# < नया डाक संदेश लिखें <EOS>
#
# > medicines such as <UNK> and beta <UNK>
# = <UNK> और अन्य दवाएं
# < ऐसे <UNK> और <UNK> <UNK> के <UNK> <EOS>
#
# > project root uri
# = परियोजना रूट यूआरआई
# < परियोजना रूट यूआरआई <EOS>
#
# > so the production side is working .
# = तो उत्पादन की समस्या पर काम हो रहा है
# < तो उत्पादन के प्रति उत्पादन की आवश्यकता है <EOS>
#
# > robert woodrow wilson
# = रोबर्ट वूड्रो विल्सन
# < <UNK> <UNK> <UNK> <UNK> <EOS>
#
# > who else would
# = भला यहाँ कौन
# < जो किसी तरह से काम करते हैं <EOS>
#
# > move a card to an empty temporary slot
# = खाली अस्थायी खाँचा पर पत्ता ले जाएँ
# < खाली अस्थायी खाँचा पर पत्ता ले जाएँ <EOS>
#
# > a wild <UNK> was running around dogs .
# = एक जंगली सूअर कुत्तों के आसपास दौड़ रहा था
# < <UNK> <UNK> के चारों ओर <UNK> गया <EOS>
#
# > this is a by square .
# = ये एक गुना का वर्ग है
# < यह एक वर्ग वर्ग के द्वारा है <EOS>
#
# Iter: 8
# Learning Rate: 1
# Time: 0h 32m 55s
# Train Loss: 1.753941151140918
#
# > rajan and sajan mishra
# = राजन एवं साजन मिश्र
# < <UNK> और <UNK> <UNK> <UNK> <EOS>
#
# > forced y position of the actor
# = कर्ता की बाध्यकारीस्थिति
# < कर्ता की बाध्यकारीस्थिति स्थिति <EOS>
#
# > his warning was for hindus .
# = <UNK> के लिए उनका यह संदेश था
# < उनकी माँ थी <EOS>
#
# > <UNK> of court proceeding is not acceptable .
# = <UNK> <UNK> को रोक लेना स्वीकृत नहीं है
# < न्यायालय का <UNK> <UNK> उचित स्वीकार्य नहीं है <EOS>
#
# > failed to add data to encoder
# = इनकोडर में आंकड़ा जोड़ने में असफल
# < इनकोडर में आंकड़ा जोड़ने में विफल <EOS>
#
# > a room which is well ventilated .
# = एक कमरा जो पूरी तरह हवादार है
# < एक <UNK> जो <UNK> का <UNK> है <EOS>
#
# > the question was much discussed .
# = इस सवाल पर बहुत बात <UNK> हुई थी
# < प्रश्न प्रश्न बहुत अधिक था <EOS>
#
# > final disposal process is in progress .
# = अंतिम निपटान की प्रक्रिया जारी है
# < अंतिम मांग प्रक्रिया प्रगति में है <EOS>
#
# > save as application
# = अनुप्रयोग मोड में ब्राउज़र प्रारंभ करें
# < अनुप्रयोग बतौर अनुप्रयोग सहेजें <EOS>
#
# > if in the islamic revolution
# = अगर इस्लामिक क्रांति के दौरान
# < यदि जनवरी में <UNK> <UNK> <EOS>
#
# Iter: 9
# Learning Rate: 1
# Time: 0h 37m 3s
# Train Loss: 1.664586654606954
#
# > no response necessary
# = कोई अनुक्रिया आवश्यक नहीं
# < कोई अनुक्रिया आवश्यक नहीं आवश्यक <EOS>
#
# > keep editor running
# = संपादक खुला रहने दें
# < संपादक में संपादक को पुनः रखें <EOS>
#
# > show or hide the side pane
# = किनारे की पट्टी को दिखायें व छुपायें
# < किनारे की पट्टी को दिखायें व छुपायें <EOS>
#
# > constraints the zoom to an axis
# = प्रतिबन्ध किसी अक्ष के लिए ज़ूम
# < प्रतिबन्ध किसी अक्ष को करने के लिए <EOS>
#
# > we were certainly too shy .
# = एक <UNK> <UNK> तो थे ही
# < हम <UNK> <UNK> की <UNK> थीं <EOS>
#
# > the file is not stored locally
# = फाइल स्थानीय रूप से जमा नहीं है
# < फाइल स्थानीय रूप से जमा नहीं है <EOS>
#
# > when will they be introduced ?
# = इन्हें कब प्रस्तुत किया जाएगा
# < जब वे कब दे जाएँगे <EOS>
#
# > department of economic and policy research
# = आर्थिक और नीति अनुसंधान विभाग
# < आर्थिक और नीति अनुसंधान विभाग <EOS>
#
# > chaudhvin ka chand
# = <UNK> का चाँद
# < <UNK> का नाम <EOS>
#
# > gaurishankar hirachand ojha
# = <UNK> <UNK> ओझा
# < <UNK> को <UNK> <UNK> <EOS>
#
# Iter: 10
# Learning Rate: 1
# Time: 0h 41m 12s
# Train Loss: 1.58542185871226
#
# > it is a matter to which the different
# = ऐसा कोई मामला लेना जो इस सबसे भिन्न हो
# < यह एक <UNK> के लिए <UNK> है <EOS>
#
# > attack with one army
# =
# < एक सेना से <UNK> हुई <EOS>
#
# > <UNK> chest is also called as <UNK> <UNK> .
# = <UNK> <UNK> को <UNK> छाती भी कहा जाता है
# < <UNK> <UNK> को <UNK> <UNK> भी कहते हैं <EOS>
#
# > no images found in archive s
# = अभिलेख में कोई चित्र नहीं मिला
# < अभिलेख में कोई चित्र नहीं मिला <EOS>
#
# > the passphrase dialog was cancelled .
# = जो पासफ्रेस आपने भरा है वह अवैध है
# < <UNK> संवाद रद्द किया गया था <EOS>
#
# > its meetings are not open for public .
# = इसकी बैठकें जनता के लिए नहीं होती
# < इसकी <UNK> सार्वजनिक <UNK> में नहीं हैं <EOS>
#
# > term repo auctions under liquidity adjustment facility
# = चलनिधि समायोजन सुविधा के अंतर्गत मीयादी रिपो <UNK>
# < <UNK> समायोजन सुविधा के अंतर्गत <UNK> <UNK> <EOS>
#
# > reply to all with custom template
# = मनपसंद टैम्प्लेट के साथ सभी को जवाब दें
# < जवाब के साथ सभी टैम्प्लेट को जवाब दें <EOS>
#
# > to be <UNK> or uncovered .
# = <UNK> करने के लिए
# < <UNK> या <UNK> होना <EOS>
#
# > nor were they concerned with feeding the destitute .
# = तो आज न उसका कोई <UNK> है
# < और न ही <UNK> थे <EOS>
#
# Iter: 11
# Learning Rate: 1
# Time: 0h 45m 17s
# Train Loss: 1.515013652181842
#
# > make the current document fill the window
# = विंडो भरने के लिये मौजूदा दस्तावेज बनाये
# < विंडो भरने के लिये मौजूदा दस्तावेज बनायें <EOS>
#
# > kde file find utility
# = केडीई फ़ाइल ढूंढने की यूटिलिटी
# < केडीई फ़ाइल ढूंढने हेतु यूटिलिटी <EOS>
#
# > <UNK> is seen in grasses .
# = <UNK> <UNK> में पाया जाता है
# < <UNK> <UNK> में देखा जाता है <EOS>
#
# > president of the people s republic of china
# = जनवादी गणराज्य चीन के राष्ट्रपति
# < चीन के गणतंत्र के राष्ट्रपति <EOS>
#
# > create desktop shortcut for this profile
# = इस प्रोफाइल के लिए डेस्कटॉप शार्टकट बनाएं
# < इस प्रोफ़ाइल के लिए डेस्कटॉप शॉर्टकट <EOS>
#
# > the major areas where bds is provided are
# = प्रमुख क्षेत्र जिनमें <UNK> उपलब्ध कराया जाता है
# < प्रमुख क्षेत्रों जहाँ <UNK> उपलब्ध होता है <EOS>
#
# > image of cd successfully created
# = सीडी छवि सफलतापूर्वक बनाया गया
# < सीडी छवि सफलतापूर्वक बनाया गया <EOS>
#
# > <UNK> vascular bundle
# = संयुक्त संवहन पूल
# < <UNK> <UNK> <UNK> <EOS>
#
# > add a new target to the project
# = जोड़ेंनया लक्ष्य को
# < जोड़ेंनया लक्ष्य को <EOS>
#
# > lock in fullscreen mode
# = फुल स्क्रीन मोड में लॉक
# < पूर्णस्क्रीन स्क्रीन मोड में लॉक करें <EOS>
#
# Iter: 12
# Learning Rate: 1
# Time: 0h 49m 22s
# Train Loss: 1.4527057491125646
#
# > go to previous wizard page
# = विजार्ड के पिछले पृष्ठ पर जाएँ
# < पिछले फ़ाइल पृष्ठ पर जाएँ <EOS>
#
# > and the population was growing at two percent
# = और जनसंख्या दो प्रतिशत से
# < और ये है दो प्रतिशत से <EOS>
#
# > switch to desktop
# = डेस्कटॉप पर स्विच करें
# < डेस्कटॉप पर स्विच करें <EOS>
#
# > maybe the hours in the denominator .
# = शायद घंटे भाजक में
# < शायद समय में <UNK> <EOS>
#
# > nokrek national park
# = नोकरेक राष्ट्रीय उद्यान
# < <UNK> राष्ट्रीय उद्यान <EOS>
#
# > annuity certain business
# = निश्चित वार्षिकी कारबार
# < वार्षिकी <UNK> व्यवसाय व्यवसाय <EOS>
#
# > itself is a perfect square .
# = एक परिशुद्ध वर्ग में ही है
# < को एक <UNK> वर्ग है <EOS>
#
# > the case was postponed <UNK> .
# = केस <UNK> रहा
# < मामले को <UNK> का <UNK> किया गया <EOS>
#
# > remove the follow up flag from the selected messages
# = चुने संदेश का प्रतिविलोपन करें
# < चयनित संदेश से फोलो अप पताका पताका निकालें <EOS>
#
# > fly by night
# = बेईमानी से रातोंरात लाभ कमाना
# < रात को आने से अधिक <EOS>
#
# Iter: 13
# Learning Rate: 1
# Time: 0h 53m 26s
# Train Loss: 1.3977764048086176
#
# > neutral or not active
# = तटस्थ या सक्रिय नहीं
# < <UNK> या <UNK> <EOS>
#
# > soil health improves through biological activity
# = जैविक क्रियाकलाप द्वारा मिट्टी को उपजाऊ बनाता है
# < <UNK> के माध्यम से मृदा स्वास्थ्य हेतु मृदा <EOS>
#
# > that would use the technology of google earth
# = जो कि गूगल अर्थ की तकनीक को इस्तेमाल करेगा
# < जो <UNK> पृथ्वी की तकनीक को इस्तेमाल करते हैं <EOS>
#
# > display the latest content of the current page
# = वर्तमान पृष्ठ की नवीनतम चीजों को दिखाएँ
# < वर्तमान पृष्ठ की नवीनतम चीजों को दिखाएँ <EOS>
#
# > subtraction memory game against tux
# = <UNK> साथ खेलने के <UNK> के बौद्धिक खेल
# < चिंटू के साथ बौद्धिक खेल के साथ बौद्धिक खेल <EOS>
#
# > reliance anil dhirubhai ambani group
# = रिलायंस अनिल धीरूभाई अंबानी समूह
# < <UNK> <UNK> <UNK> <UNK> <UNK> समूह <EOS>
#
# > earliest finish time allowed by dependencies
# = डिपेंडेंसीज़ द्वारा स्वीकार्य <UNK> समाप्ति समय
# < <UNK> द्वारा स्वीकार्य <UNK> समय का <UNK> <EOS>
#
# > failed to load remote file .
# = दस्तावेज फिर लोड करने में विफल
# < दूरस्थ फाइल लोड करने में विफल <EOS>
#
# > we decided to take the next big step
# = हमने अगला बड़ा कदम लेने का निर्णय लिया
# < हम अगले बड़े चरण को <UNK> कर दिया <EOS>
#
# > religion in ancient rome
# = प्राचीन रोम में धर्म
# < प्राचीन <UNK> में धर्म का धर्म <EOS>
#
# Iter: 14
# Learning Rate: 1
# Time: 0h 57m 29s
# Train Loss: 1.3447646290105189
#
# > my father has just come home .
# = मेरे पापा अभी अभी घर वापस आएँ हैं
# < मेरा पिता अभी ही घर आ चुका है <EOS>
#
# > hindustan <UNK> limited
# = हिन्दुस्तान <UNK> लिमिटेड
# < <UNK> <UNK> लिमिटेड <EOS>
#
# > failed to create pipeline
# = पाइप्लाइन बनाने में विफल
# < बनाने में विफल <EOS>
#
# > i am all for <UNK> their creative capabilities .
# = मैं उनकी क्षमता के <UNK> उपयोग का पक्षधर हूं
# < मैं अपनी <UNK> की <UNK> अपनी <UNK> हूं <EOS>
#
# > how is it going in the fish market ?
# = मछली बाज़ार में कैसा चल रहा है
# < मछली बाजार में कितना कितना है <EOS>
#
# > change in name of bank
# = बैंक के नाम में परिवर्तन
# < बैंक के नाम में परिवर्तन <EOS>
#
# > print this calendar
# = पंचांग मुद्रित करें
# < पंचांग को छापें <EOS>
#
# > <UNK> may be present in cases of paralysis
# = पक्षाघात के मामलो में पेशी <UNK> हो सकती है
# < <UNK> के <UNK> के कारण विद्यमान हो सकता है <EOS>
#
# > the chairman was given an honourable farewell .
# = अध्यक्ष की <UNK> विदाई की गई
# < <UNK> को <UNK> <UNK> दिया गया <EOS>
#
# > tulsi <UNK> long live tulsi .
# = <UNK> तुलसी अमर <UNK>
# < <UNK> <UNK> <UNK> <UNK> <EOS>
#
# Iter: 15
# Learning Rate: 1
# Time: 1h 1m 32s
# Train Loss: 1.2958877364395933
#
# > at the head to aid and advise
# = सहायता और सलाह देने के लिए प्रधान
# < सहायता और सलाह के लिए प्रस्ताव पर <EOS>
#
# > account maintained for finished goods .
# = तैयार माल के लिए रखा गया खाता
# < लेखा माल के लिए रखा जाने वाला लेखा <EOS>
#
# > uefa champions league final
# = २००८ यूईएफए चैंपियंस लीग फाइनल
# < यूईएफए यूईएफए चैंपियंस लीग फाइनल <EOS>
#
# > to make office environment friendly and eco friendly
# = कार्यालय परिवेश को <UNK> <UNK> और पर्यावरण अनुकूल बनाना
# < पर्यावरण पर्यावरण और <UNK> <UNK> के लिए <UNK> <EOS>
#
# > you can actually do this in your head
# = आप इसे दिमाग़ में कर सकते हो
# < आप इसे अपने <UNK> में कर सकते हैं <EOS>
#
# > interim government of the independent india
# = स्वाधीन भारत की अंतरिम सरकार
# < स्वतंत्र भारत की <UNK> सरकार <EOS>
#
# > list of installed web applications
# = अधिष्ठापित वेब अनुप्रयोगों की सूची
# < संस्थापित वेब अनुप्रयोगों के अनुप्रयोगों की सूची <EOS>
#
# > an idea or thought
# = एक विचार या चिंतन
# < एक विचार या सोचा <EOS>
#
# > improve access of farmers to wider markets
# = विस्तृत बाजार तक किसानों की पहुंच में सुधार
# < <UNK> बाजार के लिए किसानों की पहुंच <EOS>
#
# > filter junk messages using spamassassin .
# = स्पैमएसेसिन के प्रयोग से कचरा डाक संदेश फ़िल्टर करें
# < संदेश से कचरा डाक संदेश फ़िल्टर फ़िल्टर करें <EOS>
#
# Iter: 16
# Learning Rate: 1
# Time: 1h 5m 35s
# Train Loss: 1.2523366639596025
#
# > has been developing a series of inventions
# = <UNK> की एक श्रृंखला का विकास कर रहा है
# < क्या विकसित है <UNK> की श्रृंखला <EOS>
#
# > settings for the depth cueing
# = गहराई के लिए सेटिंग्स
# < गहराई के लिए सेटिंग्स <EOS>
#
# > there are no messages in this folder .
# = इस फ़ोल्डर में कोई संदेश नहीं है
# < इस फ़ोल्डर में कोई संदेश नहीं है <EOS>
#
# > minimum height set
# = न्यूनतम ऊँचाई सेट
# < न्यूनतम ऊँचाई सेट <EOS>
#
# > we shall arrange for your maintenance .
# = हम लोग तुम्हारे खाने पहनने को बन्दोबस्त कर देंगे
# < हम तुम्हारी चाल को तरजीह देंगे <EOS>
#
# > the <UNK> is not good .
# = <UNK> अच्छी नही होती है
# < <UNK> अच्छा नहीं है <EOS>
#
# > international capital market
# = अंतर्राष्ट्रीय पूंजी बाजार
# < अंतर्राष्ट्रीय पूंजी बाजार <EOS>
#
# > process of sorting or keeping apart
# = चुनने या विलग करने की प्रक्रिया
# < या समय का निर्माण करने की प्रक्रिया <EOS>
#
# > sidebar is visible
# = बाजू पट्टी दृश्यमान है
# < बाजू की पट्टी दृश्यमान है <EOS>
#
# > cannot add smimeenckeyprefs attribute
# = गुण में जोड़ नहीं सकता है
# < गुण जोड़ नहीं सकता है <EOS>
#
# Iter: 17
# Learning Rate: 1
# Time: 1h 9m 39s
# Train Loss: 1.212145661909304
#
# > empathy should reduce the location s accuracy
# = एंपेथी स्थान सटीकता को कम करना चाहिए
# < एंपेथी स्थान के <UNK> को कम करना चाहिए <EOS>
#
# > this will happen when the earth is shaken shaken
# = जब ज़मीन बड़े ज़ोरों में हिलने लगेगी
# < जब धरती काँप उठेगी तो ही हिलने होगा <EOS>
#
# > should brasero filter broken symbolic links
# = क्या ब्रैसेरो टूटी सांकेतिक कड़ी फिल्टर करता है
# < क्या ब्रैसेरो टूटी सांकेतिक कड़ी फिल्टर नहीं करता है <EOS>
#
# > the drive is busy
# = यह ड्राइव व्यस्त है
# < यह ड्राइव व्यस्त व्यस्त है <EOS>
#
# > red concentrated tobacco area
# = तंबाकू की घनी खेती वाला लाल क्षेत्र
# < लाल <UNK> की <UNK> शक्ति <EOS>
#
# > duration of the animation in milliseconds
# = चल छवि की अवधि मिलीसेकेंड में
# < चल छवि के अवधि मिलीसेकेंड में <EOS>
#
# > it takes place in the sixth month .
# = यह धार्मिक क्रिया <UNK> महीने की जाती है
# < यह <UNK> महीने में <UNK> हो जाती है <EOS>
#
# > his words went straight to the heart .
# = उसके बोल दिलों में उतर जाते थे
# < उसके <UNK> ने दिल में <UNK> <UNK> <EOS>
#
# > no local printers found
# = कोई स्थानीय प्रिंटर नहीं पाया
# < कोई स्थानीय प्रिंटर नहीं मिला <EOS>
#
# > there is medicinal or surgical treatment
# = इसका औषधीय या शल्य चिकित्सा है
# < <UNK> उपचार या शारीरिक उपचार होता है <EOS>
#
# Iter: 18
# Learning Rate: 1
# Time: 1h 13m 43s
# Train Loss: 1.173499567548347
#
# > electronic filing of central excise returns
# = केंद्रीय उत्पाद शुल्क विवरणी की इलेक्ट्रॉ निक फाइलिंग
# < केन्द्रीय उत्पाद शुल्क विवरणी की इलेक्ट्रॉनिक फाइलिंग <EOS>
#
# > she did it for three years
# = उन्होंने ये साल तक किया
# < उसने कुछ तीन साल तक किया <EOS>
#
# > category education in tamil nadu
# = <UNK> में शिक्षा
# < तमिलनाडु में <UNK> शिक्षा का वर्ग <EOS>
#
# > the <UNK> at your <UNK> store
# = <UNK> स्टोर पर बैठा <UNK>
# < <UNK> <UNK> <UNK> पर <UNK> <EOS>
#
# > how to make a complaint
# = शिकायत <UNK> करनी है
# < शिकायत कैसे दर्ज करना है <EOS>
#
# > <UNK> is a common example of mechanical vector .
# = <UNK> मक्खी भौतिक <UNK> का सामान्य उदाहरण है
# < <UNK> <UNK> <UNK> का एक सामान्य उदाहरण है <EOS>
#
# > he was denied the notice of discharge .
# = उसने <UNK> सूचना को अस्वीकार कर दिया
# < उसे <UNK> की सूचना स्वीकार की गई <EOS>
#
# > will you work a little miracle for me ?
# = क्या मेरे लिए एक छोटा सा चमत्कार करोगे
# < तुम मेरे लिए थोड़ा स्थान पर काम करेगा <EOS>
#
# > that attracted over students .
# = जो छात्रों को आकर्षित किया
# < जो छात्रों से अधिक <UNK> को प्रभावित करते हैं <EOS>
#
# > the reservation of posts was done in advance .
# = पदों का आरक्षण पहले से हुआ था
# < <UNK> का आरक्षण अग्रिम में किया गया <EOS>
#
# Iter: 19
# Learning Rate: 1
# Time: 1h 17m 49s
# Train Loss: 1.1374409422097393
#
# > list of universities and higher education colleges in london
# = लंदन के विश्वविद्यालय
# < लंदन में विश्वविद्यालय की <UNK> एवं उच्च शिक्षा <EOS>
#
# > please select a disc image .
# = कृपया कोई डिस्क छवि चुनें
# < कृपया कोई डिस्क छवि चुनें <EOS>
#
# > or you could pay eight times the going rate
# = या फिर आप आठ गुना दाम दे सकते थे
# < या आप गुना कर सकते हैं <EOS>
#
# > gibraltar city hall
# = जिब्राल्टर सिटी हॉल
# < जिब्राल्टर सिटी हॉल <EOS>
#
# > screen actors guild award
# = स्क्रीन <UNK> <UNK> अवार्ड्स
# < स्क्रीन <UNK> <UNK> <UNK> <UNK> <EOS>
#
# > animal welfare organizations are running many projects
# = जंतु हितैषी संस्थान अनेक योजनाएं चला रहा है
# < पशु कल्याण संगठन कई परियोजनाएं चल रहे हैं <EOS>
#
# > prompt while marking multiple messages
# = बहुल संदेश चिह्नित करने के दौरान प्रांप्ट करें
# < बहुल संदेश चिह्नित करने के दौरान प्रांप्ट करें <EOS>
#
# > the manufacturer was facing serious financial crisis .
# = <UNK> बड़ी <UNK> परेशानी का सामान कर रहे थ
# < <UNK> के प्रति गंभीर वित्तीय संकट थी <EOS>
#
# > they both spoke the same language .
# = उन दोनों की एक ही भाषा थी
# < वे दोनों ही एक भाषा भाषा है <EOS>
#
# > attestation can not be done in absence
# = <UNK> अनुपस्थिति में नहीं किया जाता
# < <UNK> में <UNK> नहीं किया जा सकता <EOS>
#
# Iter: 20
# Learning Rate: 1
# Time: 1h 21m 53s
# Train Loss: 1.102708374673844
#
# > the quality of being <UNK> .
# = धारणा <UNK> होने की गुणवत्ता
# < <UNK> होने की गुणवत्ता <EOS>
#
# > <UNK> <UNK> died at an age of years
# = गौतम बुद्ध की म्रित्यु ८० वर्ष मे हुइ थी
# < <UNK> <UNK> की आयु में वर्ष है <EOS>
#
# > user name and password do not match !
# = उपयोगकर्ता नाम और पासवर्ड मेल नहीं खाते
# < उपयोक्ता नाम और पासवर्ड मेल नहीं खाता <EOS>
#
# > the legal status of this land is controversial .
# = ये जमीन कानूनी हैसियत से <UNK> है
# < इस भूमि की कानूनी स्थिति में है <EOS>
#
# > collapse all threads
# = सभी लड़ियाँ समेटें
# < सभी लड़ियाँ समेटें <EOS>
#
# > failed to open for writing
# = प्लेयर प्रक्रिया बन्द करने में असफल
# < लिखने के लिए खोलने में विफल <EOS>
#
# > they are also closely related to the python .
# = ये अजगर से भी काफी निकट हैं
# < ये लोगों से संबंधित <UNK> भी हैं <EOS>
#
# > returns less than
# = इससे कम लौटाता है
# < इससे कम लौटाता है <EOS>
#
# > we shall definitely do so .
# = ऐसा हम अवश्य करेंगे
# < हम ऐसा करेंगे <EOS>
#
# > sc roll month view by a week
# = सप्ताह द्वारा महिना देखकर स्क्रोल करें
# < सप्ताह द्वारा महिना देखकर स्क्रोल करें <EOS>
#
# Iter: 21
# Learning Rate: 1
# Time: 1h 25m 55s
# Train Loss: 1.070334412408865
#
# > not part of certificate
# = प्रमाण पत्र का हिस्सा नहीं
# < प्रमाणपत्र का हिस्सा नहीं <EOS>
#
# > modifier tone letters
# = परिवर्धक टोन कुंजियाँ
# < <UNK> टोन के लिए चर पत्र <EOS>
#
# > when the earth shall be rocked
# = जब ज़मीन बड़े ज़ोरों में हिलने लगेगी
# < जब धरती थरथराकर काँप उठेगी <EOS>
#
# > cash inward outward register
# = आवक जावक नकदी रजिस्टर
# < नकदी आवक आवक आवक रजिस्टर रजिस्टर <EOS>
#
# > lookup in local address book only
# = स्थानीय पता पुस्तिका में देखें
# < स्थानीय पता पुस्तिका में देखें <EOS>
#
# > toggles whether the reply to field is displayed
# = यदि जवाब दें क्षेत्र प्रदर्शित है तो टॉगल करें
# < यदि जवाब दें क्षेत्र प्रदर्शित है तो टॉगल करें <EOS>
#
# > generic routing <UNK>
# = प्रजातीय <UNK> <UNK>
# < <UNK> <UNK> <UNK> <UNK> <EOS>
#
# > he showed them the path to god .
# = उनको ईश्वर लाभ का मार्ग बताया
# < फिर उसे ख़ुदा पर उसको दिखाया गया <EOS>
#
# > reset compatibility options to defaults
# = संगतता विकल्पों तयशुदा में रीसेट करें
# < रीसेट विकल्प तयशुदा के लिए रीसेट करें <EOS>
#
# > is definitely divisible by so will be
# = से भाग हो सकता है तो
# < से भाग सकते है तो से भाग होंगे <EOS>
#
# Iter: 22
# Learning Rate: 1
# Time: 1h 29m 59s
# Train Loss: 1.0408198209956345
#
# > this fact is based on possibility .
# = यह तथ्य अनुमान पर आधारित है
# < यह तथ्य <UNK> पर आधारित है <EOS>
#
# > kded favicon module
# = केडीईडी <UNK> मॉड्यूलComment
# < केडीईडी <UNK> <UNK> मॉड्यूल <EOS>
#
# > so be careful later on .
# = तो बाद में सावधान रहें
# < तो बाद में <UNK> <EOS>
#
# > new password does not follow password rules
# = नया कूटशब्द कूटशब्द नियम का अनुसरण करता है
# < नया कूटशब्द कूटशब्द नियम का अनुसरण नहीं करता है <EOS>
#
# > always request rea d receipt
# = हमेशा पठित रसीद आग्रह करें
# < हमेशा पठित रसीद के आग्रह भेजें <EOS>
#
# > show the task preview pane
# = कार्य पूर्वावलोकन पट्टी दिखाएँ
# < कार्य पूर्वावलोकन पट्टी दिखाएँ <EOS>
#
# > by heaven with all its tracks
# = गवाह है धारियोंवाला आकाश
# < गवाह है धारियोंवाला आकाश <EOS>
#
# > he was lord vishnu s sixth incarnation
# = वे भगवान विष्णु का षष्ठम अवतार थे
# < वे भगवान विष्णु का स्वामी विष्णु का कारण था <EOS>
#
# > flag of kazakhstan
# = <UNK> का ध्वज
# < <UNK> का ध्वज <EOS>
#
# > let me do a real weird one .
# = मुझे एक अजीब सवाल लेने दो
# < मुझे एक असली ही बात कर दो <EOS>
#
# Iter: 23
# Learning Rate: 1
# Time: 1h 34m 1s
# Train Loss: 1.011753180610663
#
# > those of you who are good at <UNK>
# = आप में से जो विज्ञापन करने में अच्छे हैं
# < तो तुम लोग यक़ीनी सदैव पर रहते हो <EOS>
#
# > to revise or append to the rules .
# = नियमों में संशोधन करना या उसमें जोड़ना
# < नियमों में संशोधन करना या जोड़ना <EOS>
#
# > this will make spamassassin more reliable but slower
# = यह को अधिक भरोसेमंद बनाएगा लेकिन धीमे रूप से
# < यह को अधिक भरोसेमंद बनाएगा लेकिन नहीं होगा <EOS>
#
# > he praised the life in the hills .
# = पर्वत <UNK> को वे बहुत <UNK> हैं
# < उसने जीवन में जीवन की <UNK> की <EOS>
#
# > whether or not to use animation .
# = एनीमेशन उपयोग करें या नहीं
# < एनीमेशन उपयोग करें या नहीं <EOS>
#
# > this is going to be very useful .
# = ऐसा हो तो उससे बहुत फायदा हो सकता है
# < यह बहुत उपयोगी होने जा सकता है <EOS>
#
# > to present or submit an account .
# = हिसाब प्रस्तुत करना अथवा पेश करना
# < किसी खाते में जमा करना या जमा करना <EOS>
#
# > when the stars are extinguished
# = फिर जब तारों की चमक जाती रहेगी
# < फिर जब तारों की चमक जाती रहेगी <EOS>
#
# > central level <UNK>
# = केन्द्रीय स्तर प्रशासन
# < केंद्रीय स्तर पर <UNK> <EOS>
#
# > image burning setup
# = छवि बर्निंग सेटअप
# < छवि बर्निंग सेटअप सेटअप है <EOS>
#
# Iter: 24
# Learning Rate: 1
# Time: 1h 38m 4s
# Train Loss: 0.983380499955414
#
# > new issue of debentures
# = <UNK> का नया निर्गम
# < <UNK> का नया निर्गम <EOS>
#
# > auto sheet feeder
# = स्वचलित शीट फीडर
# < स्वत पत्र जब <UNK> <EOS>
#
# > nationalist congress party
# = <UNK> कांग्रेस पार्टी
# < <UNK> कांग्रेस का पार्टी पार्टी <UNK> था <EOS>
#
# > pharaoh and his people pursued them at sunrise
# = ग़रज़ तो रात ही को चले गए
# < सुबह व रात उनको उनका ज़िक्र ले गया <EOS>
#
# > supervision and management of the wing registry .
# = विंग रजिस्ट्री का <UNK> तथा प्रबन्धन कार्य
# < <UNK> रजिस्ट्री के लिए पर्यवेक्षण और प्रबंधन <EOS>
#
# > a salmonella infection is a <UNK> illness .
# = <UNK> संक्रमण एक <UNK> रोग है
# < <UNK> संक्रमण एक <UNK> रोग है <EOS>
#
# > similar to or resembling the breast
# = स्तन या चूचुक के समान या समरूप
# < समान या स्तन के समान या समान होना <EOS>
#
# > apply advanced power management settings
# = उन्नत पावर प्रबंधन सेटिंग्स लागू करें
# < पावर पावर प्रबंधन विन्यास सेटिंग्स लागू करें <EOS>
#
# > cost accounting is an important subject
# = लागत लेखा विधी एक महत्वपूर्ण विषय है
# < लागत लेखा लेखा एक महत्वपूर्ण विषय है <EOS>
#
# > x x
# = के लिये डिफॉल्ट
# < एक्स <EOS>
#
# Iter: 25
# Learning Rate: 1
# Time: 1h 42m 6s
# Train Loss: 0.9572145949378329
#
# > they put it back into the market .
# = वापस अपने बाजारों में इस्तेमाल करते हैं
# < उन्होंने इसे बाजार में वापस वापस लिया <EOS>
#
# > powers and duties of officers and employees
# = अधिकारियों तथा कर्मचारियों की शक्तियां एवं ड्यूटी
# < अधिकारियों व कर्मचारियों की शक्तियां एवं कर्तव्य <EOS>
#
# > shows the brightness popup slider
# = चमकीलापन पॉपअप स्लाइडर को दिखाता है
# < प्रदर्शित पॉपअप स्लाइडर <UNK> दिखाता है <EOS>
#
# > initiation of new projects and release of funds
# = नई परियोजनाओं की शुरूआत और निधि जारी करना
# < नई परियोजनाओं की <UNK> और जारी करना <EOS>
#
# > cookies set by this page
# = इस पृष्ठ द्वारा सेट कुकी
# < इस पृष्ठ द्वारा सेट को पुनः सेट करें <EOS>
#
# > i have no interest in ordinary people .
# = मुझे साधारण लोगों में कोई दिलचस्पी नही है
# < मुझे साधारण लोगों में कोई रुचि नहीं है <EOS>
#
# > the page label of the document to display .
# = दिखाने के लिये दस्तावेज का पेज लेबल
# < दिखाने के लिये दस्तावेज का पेज <EOS>
#
# > online messages alerts to users on business related matters
# = व्यापार संबंधित मामलों पर <UNK> को ऑनलाइन संदेश <UNK>
# < व्यापार संबंधित मामलों पर ऑनलाइन संदेश <UNK> <UNK> <EOS>
#
# > cultural complexities have arisen due to historical circumstances .
# = ऐतिहासिक परिस्थितियों के कारण सांस्कृतिक जटिलताएं पैदा हुई हैं
# < <UNK> <UNK> के कारण <UNK> हो चुके हैं <EOS>
#
# > tenders of the government
# = सरकार की निविदाएं
# < सरकार की निविदाएं निविदाएं <EOS>
#
# Iter: 26
# Learning Rate: 1
# Time: 1h 46m 9s
# Train Loss: 0.9325903780260927
#
# > do not use config file
# = कॉन्फ़िग फ़ाइल इस्तेमाल नहीं करें
# < कॉन्फ़िग फ़ाइल इस्तेमाल का उपयोग मत करें <EOS>
#
# > muslim conquest in the indian subcontinent
# = भारतीय उपमहाद्वीप का इस्लामी इतिहास
# < भारतीय उपमहाद्वीप में मुस्लिम इस्लामी इतिहास <EOS>
#
# > propagation of wild life and fisheries
# = वन्य जीवन तथा <UNK> का प्रसार
# < <UNK> और <UNK> जीवन का <UNK> <EOS>
#
# > show api documentation
# = एपीआई प्रलेखन दिखाएँ
# < प्रलेखन प्रलेखन दिखाएँ <EOS>
#
# > <UNK> or production of something
# = किसी वस्तु का प्रोत्साहन या उत्पादन
# < किसी वस्तु का <UNK> या उत्पादन <EOS>
#
# > we have our three zeroes at the end .
# = हमारे पास अंत मे शून्य होगा
# < हमारे पास अंत में <UNK> <UNK> हैं <EOS>
#
# > post graduate institute of medical education and research chandigarh
# = पोस्ट <UNK> इंस्टीट्यूट ऑफ मेडिकल एजुकेशन एंड रिसर्च <UNK>
# < <UNK> मेडिकल शिक्षा एवं अनुसंधान संस्थान <UNK> संस्थान <EOS>
#
# > the requested functionality is not implemented for this protocol
# = अनुरोधित कार्यशीलता इस प्रोटोकॉल के लिए लागू नहीं है
# < अनुरोधित कार्यशीलता इस प्रोटोकॉल के लिए लागू नहीं है <EOS>
#
# > remote batch also known as <UNK> .
# = दूरवर्ती समूह के नाम से भी जाना जाता है
# < सुदूर समूह को <UNK> भी कहते हैं <EOS>
#
# > group of volcanic islands in the bay of bengal
# = बंगाल की खाड़ी में ज्वालामुखी द्वीप का समूह
# < बंगाल की खाड़ी में <UNK> द्वीप का समूह <EOS>
#
# Iter: 27
# Learning Rate: 1
# Time: 1h 50m 12s
# Train Loss: 0.9062017439777965
#
# > i call to witness the mount sinai
# = तूर की क़सम
# < तो मैं भी ख़ुश करते हूँ <EOS>
#
# > proclaim the glory of your lord
# = और अपने परवरदिगार की बड़ाई करो
# < और अपने परवरदिगार की बड़ाई करो <EOS>
#
# > so the second cable is inches and
# = दूसरी केबल इंच की है हम वही
# < तो दूसरे भाग इंच और <EOS>
#
# > email begins with
# = ईमेल शुरु होता है
# < ईमेल शुरु होता है <UNK> से <EOS>
#
# > those who rebelled in the cities
# = ये लोग मुख़तलिफ़ शहरों में सरकश हो रहे थे
# < वे लोग कि जिन्होंने देशो में सरकशी की <EOS>
#
# > edit as script
# = संपादन जैसे स्क्रिप्ट
# < संपादन जैसे स्क्रिप्ट को स्क्रिप्ट है <EOS>
#
# > show message preview below the message list
# = संदेश सूची के नीचे संदेश पूर्वावलोकन दिखाता है
# < संदेश सूची के नीचे संदेश पूर्वावलोकन दिखाता है <EOS>
#
# > file system information shown in list
# = सूची में दिखाई गई फ़ाइल तंत्र <UNK>
# < सूची में दिखाई जाने वाली फ़ाइल सिस्टम <EOS>
#
# > ignore changes in case
# = केस में परिवर्तनों को नज़र अंदाज़ करें
# < केस में परिवर्तनों को नज़र अंदाज़ करें <EOS>
#
# > do background check quietly
# = पीछे से जांचे
# < पृष्ठभूमि जाँच <UNK> <EOS>
#
# Iter: 28
# Learning Rate: 1
# Time: 1h 54m 16s
# Train Loss: 0.8839845337149179
#
# > the number of columns the widget should span
# = स्तंभों की संख्या जिसमें विजेट स्पैन करना चाहिए
# < स्तंभों की संख्या जिसमें विजेट स्पैन करना चाहिए <EOS>
#
# > square with dots
# = बिन्दुओं के साथ वर्ग
# < बिन्दुओं को छोड़ें <EOS>
#
# > document compression utility
# = प्रलेख संपीडन उपयोगिता
# < दस्तावेज़ <UNK> यूटिलिटी <EOS>
#
# > the name of her father was <UNK> singh .
# = उनके पिता का नाम रत्नसिंह था
# < उसके पिता का नाम <UNK> सिंह था <EOS>
#
# > importing outlook express data
# = आउटलुक एक्सप्रेस आंकड़ा आयात कर रहा है
# < आउटलुक एक्सप्रेस आंकड़ा आयात कर रहा है <EOS>
#
# > payments due as
# = <UNK> के रूप में देय भुगतान
# < के रूप में भुगतान करें <EOS>
#
# > ignore changes in the amount of whitespace
# = परिवर्तनों को श्वेतस्थान की मात्रा में नज़र अंदाज़ करें
# < परिवर्तनों को श्वेतस्थान में नज़र अंदाज़ करें <EOS>
#
# > bahlul khan lodi
# = <UNK> खान लोधी
# < <UNK> खान पैलेस <EOS>
#
# > different header for the first page
# = प्रथम पृष्ठ के लिए भिन्न शीर्ष सूचना
# < प्रथम पृष्ठ के लिए अलग शीर्ष शीर्ष शीर्षिका <EOS>
#
# > serial line internet protocol
# = क्रम रेखा इंटरनेट प्रोटोकॉल
# < उत्तरी लाइन इंटरनेट प्रोटोकॉल <EOS>
#
# Iter: 29
# Learning Rate: 1
# Time: 1h 58m 22s
# Train Loss: 0.860914796381872
#
# > cogl debugging flags to unset
# = डिबगिंग फ्लैग अनसेट किया जाना है
# < डिबगिंग फ्लैग अनसेट किया जाना है <EOS>
#
# > mark the selected messages as junk
# = चयनित संदेश कचरा डाक के रूप में चिह्नित करें
# < चयनित संदेश कचरा डाक के रूप में चिह्नित करें <EOS>
#
# > his home will be the abyss .
# = उसकी माँ होगी गहरा खड्ड
# < उसका घर <UNK> में <UNK> रहेगा <EOS>
#
# > enable automatic spell correction
# = स्वचालित वर्तनी सुधार सक्षम करें
# < स्वचालित वर्तनी सुधार सुधार सक्षम करें <EOS>
#
# > toggle bookmark at the current line position
# = टॉगल एट लकीर स्थिति
# < टॉगल एट लकीर स्थिति <EOS>
#
# > trade finance scheme raw material assistance scheme
# = व्यापार वित्त योजना <UNK> सहायता योजना
# < व्यापार वित्त योजना सहायता योजना <EOS>
#
# > medulla <UNK> composed mainly of chromaffin cells .
# = अधिवृक्क <UNK> मुख्यत <UNK> कोशिकाओं से निर्मित होता है
# < मज्जा <UNK> को <UNK> में निर्मित होना <EOS>
#
# > my media year
# = मेरा मीडिया वर्ष
# < मेरा <UNK> साल के <UNK> <EOS>
#
# > a number of flower bearing <UNK> have columns .
# = असंख्य फूलों से लदे <UNK> में स्तंभ होते हैं
# < <UNK> <UNK> की संख्या में स्तंभ <EOS>
#
# > sikh light infantry
# = सिख लाइट <UNK>
# < <UNK> लाइट <UNK> <EOS>
#
# Iter: 30
# Learning Rate: 1
# Time: 2h 2m 28s
# Train Loss: 0.8398343014777357
#
# > to be <UNK>
# = <UNK> के लिए
# < का <UNK> होना <EOS>
#
# > spreading widely from the center .
# = केंद्र से व्यापक रूप से फैल जाना
# < केंद्र से <UNK> से <UNK> <EOS>
#
# > whether the selected text color has been set
# = क्या चयनित पाठ रंग सेट किया गया है
# < क्या चयनित पाठ रंग सेट किया गया है <EOS>
#
# > use a real folder for trash
# = रद्दी के लिए एक वास्तविक फ़ोल्डर का उपयोग करेंः
# < रद्दी के लिए वास्तविक फ़ोल्डर का उपयोग करेंः <EOS>
#
# > mesh can be an <UNK> .
# = <UNK> एक दरार या <UNK> हो सकता है
# < <UNK> एक <UNK> को <UNK> किया जा सकता है <EOS>
#
# > demand collection balance
# = मांग वसूली शेष
# < मांग वसूली शेष <EOS>
#
# > edit breakpoint properties
# = ब्रेकपाइंट गुण संपादन करें
# < गुण संपादन करें <EOS>
#
# > open a recently used document
# = हाल में प्रयुक्त दस्तावेज खोलें
# < हाल में प्रयुक्त दस्तावेज खोलें <EOS>
#
# > and they said something very interesting to me .
# = और उन्होंने बहुत दिलचस्प चीज कही
# < और उन्होंने मेरे लिए कुछ दिलचस्प दिलचस्प <EOS>
#
# > how are imperialism and religion related ?
# = <UNK> से और धर्म से क़्या संबंध
# < <UNK> और धर्म से संबंधित क्या <EOS>
#
# Iter: 31
# Learning Rate: 1
# Time: 2h 6m 33s
# Train Loss: 0.8189848151306669
#
# > sheep and goat feed
# = भेड़ तथा बकरी चारा
# < <UNK> और <UNK> चारा <UNK> <EOS>
#
# > libburn library could not be initialized
# = लाइब्रेरी नहीं आरंभीकृत की जा सकी
# < लाइब्रेरी नहीं आरंभीकृत की जा सकी <EOS>
#
# > ii details of conference program
# = सम्मेलन कार्यक्रम के विवरण
# < सम्मेलन कार्यक्रम का विवरण <EOS>
#
# > eknath did not loose his temper .
# = एकनाथ को जरा भी क्रोध नहीं आया
# < <UNK> ने अपनी <UNK> की भी नहीं हुई <EOS>
#
# > they looked out towards the road .
# = उन लोगों ने रास्ते की तरफ देखा
# < वे सड़क के प्रति देख रहे <EOS>
#
# > by the morning when it <UNK> .
# = और प्रातःकाल जबकि वह पूर्णरूपेण प्रकाशित हो जाए
# < और सुबह की जब रौशन हो जाए <EOS>
#
# > extra output was generated during package manager operation
# = पैकेज प्रबन्धन प्रक्रिया के दौरान अतिरिक्त सन्देश मिले
# < पैकेज प्रबंधक के दौरान अतिरिक्त आउटपुट ऑपरेशन उत्पन्न <EOS>
#
# > could not display help
# = मदद दिखाई नहीं जा सकी
# < मदद दिखाई नहीं जा सकी <EOS>
#
# > save file as
# = ऐसे फाइल सहेजें
# < सहेजने के रूप में फाइल सहेजें <EOS>
#
# > this will be the real test .
# = यही असली परीक्षा होगी
# < यह असली परीक्षण किया जाएगा <EOS>
#
# Iter: 32
# Learning Rate: 1
# Time: 2h 10m 38s
# Train Loss: 0.7984338219432344
#
# > connection has been refused
# = कनेक्शन अस्वीकृत किया गया है
# < कनेक्शन का <UNK> किया गया है <EOS>
#
# > unable to unmount
# = उतारने में असमर्थ
# < त्रुटिः बाइंड में असमर्थ <EOS>
#
# > who may employ an agent
# = एजेन्ट कौन रख सकता है
# < कौन <UNK> में काम करने देता है <EOS>
#
# > on honoured leaves
# = पवित्र पन्नों में अंकित है
# < बड़े बातों पर स्थित <EOS>
#
# > zoom in increase font size
# = ज़ूम इंच आकार
# < ज़ूम इंच आकार <EOS>
#
# > show hidden files
# = छुपी फ़ाइलें दिखाएँ
# < छुपी हुई फ़ाइलों को दिखाएँ <EOS>
#
# > draw bands in the spectrometer
# = <UNK> में बैंड आरेखित करें
# < <UNK> में बैंड को आरेखित करें <EOS>
#
# > shanghai world financial center
# = शंघाई विश्व वित्तीय केन्द्र
# < विश्व विश्व वित्तीय केन्द्र <EOS>
#
# > failure to observe the law .
# = कानून की अवज्ञा करना
# < कानून को अंतरण कर पाना <EOS>
#
# > the government was highly perturbed by his activities .
# = उनकी गतिविधियों से <UNK> सरकार बहुत घबरा उठी
# < उसके कार्यकलाप को <UNK> बहुत प्रभावित हुआ <EOS>
#
# Iter: 33
# Learning Rate: 1
# Time: 2h 14m 42s
# Train Loss: 0.7792978297369667
#
# > the number of axes on the device
# = युक्ति पर अक्षों की संख्या
# < युक्ति पर अक्षों की संख्या <EOS>
#
# > will you go by train ?
# = तुम रेलगाड़ी से जाओगे क्या
# < तुम बजे से क्या जाओगे <EOS>
#
# > disease management in citrus
# = नींबू में एकीकृत रोग प्रबंधन
# < <UNK> में रोग प्रबंधन <EOS>
#
# > the actor wrapped by this data
# = इस डेटा से लिपटे कर्ता
# < इस डेटा से लिपटे कर्ता <EOS>
#
# > history origin of language history of linguistics
# = <UNK> भाषा की उत्पत्ति भाषाविज्ञान का इतिहास
# < <UNK> भाषा का इतिहास का इतिहास <EOS>
#
# > the bank maintains its goodwill among customers .
# = बैक ने ग्राहकों के मध्य अपनी साख बनाए रखी
# < बैंक ने अपने सारे <UNK> में <UNK> किया <EOS>
#
# > he saved up his money for the tongs .
# = इसीलिए <UNK> ने अपने पैसे बचा रखें
# < उसने <UNK> के लिए अपने पैसे बचा लिया <EOS>
#
# > and the roasting in hell .
# = फिर भड़कती हुई आग में उन्हें झोंका जाना है
# < फिर भड़कती हुई आग में उन्हें झोंका जाना है <EOS>
#
# > <UNK> are <UNK> insects of the family <UNK> .
# = <UNK> <UNK> परिवार के एक <UNK> <UNK> हैं
# < <UNK> <UNK> <UNK> <UNK> के <UNK> कीट होते हैं <EOS>
#
# > open the specified playlist as an audio project
# = बतौर ऑडियो परियोजना निर्दिष्ट गीतसूची खोलें
# < बतौर ऑडियो परियोजना निर्दिष्ट गीतसूची खोलें <EOS>
#
# Iter: 34
# Learning Rate: 1
# Time: 2h 18m 46s
# Train Loss: 0.7594432600178443
#
# > digitization of maps and updating of land records
# = मानचित्र के <UNK> और भूमि अभिलेखों का अद्यतन
# < भूमि रिकार्ड का <UNK> और अद्यतन का <UNK> <EOS>
#
# > provisions for taxation of a cooperative society
# = सहकारी समितियों के कराधान के लिए सावधान
# < सहकारी समितियों के कराधान के लिए प्रावधान <EOS>
#
# > performed by way of the mouth .
# = मुंह से किया हुआ
# < मुंह से किया हुआ <EOS>
#
# > so they have to take their shoes off
# = अतः उन्हे <UNK> निकालने पड़ते हैं
# < इसलिए उन्हें <UNK> काट लेना होगा <EOS>
#
# > banaras hindu university
# = काशी हिन्दू विश्वविद्यालय
# < काशी हिन्दू विश्वविद्यालय <EOS>
#
# > failed to remove attachments from messages .
# = संदेश से संलग्नक को हटाने में विफल
# < संदेश से संलग्नक को हटाने में विफल <EOS>
#
# > a generic xlib dock applet
# = जेनेरिक डाक एप्लेट
# < जेनेरिक डाक से एप्लेट एप्लेट <EOS>
#
# > official audio source webpage
# = आधिकारिक ऑडियो स्रोत वेबपृष्ठ
# < के लिये ऑडियो स्रोत वेबपृष्ठ <EOS>
#
# > chances in years to complete a course
# = साल में संभावना एक कोर्स पूरा करने के लिए
# < साल में पूरा काम पूरा करने में <EOS>
#
# > the union government of india .
# = देश की संघ सरकार
# < भारत की संघ सरकार <EOS>
#
# Iter: 35
# Learning Rate: 1
# Time: 2h 22m 51s
# Train Loss: 0.7411521611593556
#
# > this type of ileus is called as <UNK> ileus
# = इस प्रकार का आंत्रावरोध <UNK> आंत्रावरोध कहलाता है
# < इस प्रकार का <UNK> <UNK> <UNK> कहलाता है <EOS>
#
# > sericulture is the technique to produce silk .
# = <UNK> पालन रेशम उत्पादन करने की तकनीक है
# < रेशम उत्पादन उत्पादन की तकनीक में होती है <EOS>
#
# > add files to the archive
# = फ़ाइलें अभिलेख में जोड़ें
# < फ़ाइलें अभिलेख में जोड़ें <EOS>
#
# > responses will not have the ip address logged .
# = जवाब नहीं होगा आईपी पता लॉग
# < जवाब होगा आईपी पता नहीं लॉग <EOS>
#
# > please fill in the following fields
# = कृपया निम्नलिखित क्षेत्र में भरेंः
# < कृपया निम्नलिखित क्षेत्र में भरेंः करेंः <EOS>
#
# > by the star as it goes down .
# = तारे की क़सम जब टूटा
# < तारे की क़सम जब टूटा <EOS>
#
# > tape worm causes <UNK> symptoms in person
# = <UNK> से व्यक्ति में <UNK> के लक्षण आते हैं
# < <UNK> <UNK> व्यक्ति में <UNK> लक्षण होते हैं <EOS>
#
# > it has also run short of money .
# = उसके पास पैसे की भी कमी हो गई है
# < उसकी मुद्रा <UNK> की भी हो गई है <EOS>
#
# > choose the difficulty level
# = कठिनाई स्तर चुनें
# < कठिनाई स्तर चुनें <EOS>
#
# > write to the local government ombudsman
# = लोकल गवर्नमेंट <UNK> को लिखें
# < स्थानीय सरकार को <UNK> में लिखें <EOS>
#
# Iter: 36
# Learning Rate: 1
# Time: 2h 26m 56s
# Train Loss: 0.7252548214216691
#
# > by the sky with its returning rain
# = साक्षी है आवर्तन वाला आकाश
# < गवाह है धारियोंवाला आकाश <EOS>
#
# > enable syncing history
# = इतिहास समन्वयन सक्षम करें
# < समन्वयन इतिहास सक्षम करें <EOS>
#
# > reset sticky tags
# = रीसेट स्टिकी टैग
# < रीसेट स्टिकी टैग टैग <EOS>
#
# > and that is exactly what it is .
# = और असल में ये यही है
# < और वास्तव में यह जो है वह है <EOS>
#
# > seven deadly sins
# = सात घातक पाप
# < सात घातक पाप <EOS>
#
# > save image to a file
# = छवि को फ़ाइल में सहेजें
# < छवि को फ़ाइल में सहेजें <EOS>
#
# > application for authorized user id
# = अधिकृत यूजर आईडी के लिए आवेदन
# < प्राधिकृत यूजर आईडी के लिए आवेदन <EOS>
#
# > <UNK> bay <UNK>
# = <UNK> बे <UNK>
# < <UNK> <UNK> <UNK> <UNK> <EOS>
#
# > <UNK> which provided to <UNK>
# = इंजील जो कि ईसा को प्रदान की गयी
# < ज़बूर जो कि दाउद को प्रदान की गयी <EOS>
#
# > compare returns
# = का परिणाम होगा
# < के लिए तुलना <EOS>
#
# Iter: 37
# Learning Rate: 1
# Time: 2h 31m 1s
# Train Loss: 0.7079568625541117
#
# > what is the meaning of this command ?
# = इस निर्देश का क्या अर्थ है
# < इस आदेश का क्या अर्थ है <EOS>
#
# > the action of abstaining
# = दूर या तटस्थ
# < दूर रहने की क्रिया <EOS>
#
# > save changes in currently selected images
# = मौजूदा चुनी छवियों में परिवर्तन सहेजें
# < मौजूदा चुनी छवियों में परिवर्तन सहेजें <EOS>
#
# > i had already sent letters and telegrams .
# = पत्र और तार तो मैंने भेजे ही थे
# < <UNK> में तो मैं सिर्फ था <EOS>
#
# > work package owner
# = कार्य पैकेज नियंत्रण
# < कार्य पैकेज नियंत्रण <EOS>
#
# > history of australia
# = ऑस्ट्रेलिया का इतिहास
# < ऑस्ट्रेलिया का इतिहास <EOS>
#
# > no users found
# = कोइ उपयोक्ता नहीं मिला
# < कोई प्रयोक्ता नहीं मिला <EOS>
#
# > and you always have to remember over or is
# = और आप हमेशा याद रखे की बटा या
# < और आपको हमेशा <UNK> रखना होगा या फिर याद करना <EOS>
#
# > board approved financial inclusion plan
# = निदेशक मंडल द्वारा अनुमोदित वित्तीय समावेशन योजना
# < बोर्ड मंडल वित्तीय समावेशन का निर्माण करते हैं <EOS>
#
# > we will call the guards .
# = देखो हरगिज़ उनका कहना न मानना
# < हम भी बुलाए लेते है सिपाहियों को <EOS>
#
# Iter: 38
# Learning Rate: 1
# Time: 2h 35m 9s
# Train Loss: 0.6915192430870368
#
# > checking for new mail
# = नई डाक के लिए जांच
# < नई डाक के लिए जांच <EOS>
#
# > select columns to be shown
# = दिखाए जाने वाले स्तम्भ को चुनेंः
# < दिखाए जाने वाले स्तंभों को चुनेंः <EOS>
#
# > goa industrial development corporation
# = गोवा औद्योगिक विकास निगम
# < गोवा औद्योगिक विकास निगम लि <EOS>
#
# > subhas stood <UNK> by his leader .
# = सुभाष इसमें <UNK> अपने नेता के पक्षधर बने रहे
# < सुभाष <UNK> अपने नेता के द्वारा <UNK> करते थे <EOS>
#
# > review of intermediary accounts
# = मध्यवर्ती लेखों की समीक्षा
# < मध्यवर्ती खातों की समीक्षा समीक्षा <EOS>
#
# > create a network game
# =
# < नेटवर्क के खेल बनाएँ <EOS>
#
# > as a <UNK> i worry
# = एक <UNK> के तौर पर मैं चिंतित
# < एक <UNK> के रूप में जो मेरी <UNK> है <EOS>
#
# > to hours a day years and
# = दैनिक १ से २ घंटे
# < दैनिक साल और २ घंटे <EOS>
#
# > only local files are supported .
# = सिर्फ स्थानीय फ़ाइलें ही समर्थित
# < सिर्फ स्थानीय फ़ाइलें ही समर्थित हैं <EOS>
#
# > show the application s version
# = अनुप्रयोग संस्करण दिखायें
# < अनुप्रयोग संस्करण दिखाएँ <EOS>
#
# Iter: 39
# Learning Rate: 1
# Time: 2h 39m 17s
# Train Loss: 0.6745135028729412
#
# > okapi wildlife reserve
# = <UNK> राष्ट्रीय उद्यान
# < <UNK> वन्य जीवन आरक्षित निधि <EOS>
#
# > link updating behavior on note rename
# = नोट के नाम बदलने पर कड़ी अद्यतन आचरण
# < नोट सूची पर <UNK> व्यवहार अद्यतन किया गया <EOS>
#
# > quiet volume up
# = आवाज बढ़ाएँ को शांत करें
# < <UNK> <UNK> को शांत करो <EOS>
#
# > but they treated our signs as false .
# = और उन्होंने हमारी आयतों को ख़ूब झुठलाया
# < और उन्होंने हमारी आयतों को ख़ूब झुठलाया <EOS>
#
# > flag of malta
# = माल्टा का ध्वज
# < का ध्वज <EOS>
#
# > clear recent applications
# = हाल ही के अनुप्रयोग साफ करें
# < हाल ही के अनुप्रयोग साफ करें <EOS>
#
# > like all the stories are about being wrong .
# = की सभी कहानियों गलत होने के बारे में हैं
# < सभी कहानियों गलत <UNK> जा रहे हैं <EOS>
#
# > at the time of the chinese invasion .
# = आक्रमण के समय तुरंत मार दिया गया
# < के समय प्राप्त होने की यात्रा <EOS>
#
# > you are searching for a king .
# = एक बादशाह को आप ढूंढ रहे हैं
# < एक बादशाह को आप ढूंढ रहे हैं <EOS>
#
# > money stock measures
# = मुद्रा स्टॉक मात्रा
# < मुद्रा स्टॉक मात्रा में खर्च <EOS>
#
# Iter: 40
# Learning Rate: 1
# Time: 2h 43m 24s
# Train Loss: 0.658593965103433
#
# > perforated tape reader
# = छिद्रित टेप पाठक
# < <UNK> टेप पाठक <UNK> <EOS>
#
# > cogl debugging flags to unset
# = डिबगिंग फ्लैग अनसेट किया जाना है
# < डिबगिंग फ्लैग अनसेट किया जाना है <EOS>
#
# > a census town in north goa .
# = उत्तरी गोवा में एक जनगणना शहर
# < उत्तरी गोवा में एक जनगणना शहर शहर <EOS>
#
# > <UNK> sen online
# = कृषण सेन अन्लाईन
# < <UNK> ऑनलाइन ऑनलाइन <UNK> <EOS>
#
# > we had been <UNK> when chacha was there .
# = <UNK> के होते हम <UNK> रहे हैं
# < <UNK> के बाद हम <UNK> थे <EOS>
#
# > <UNK> <UNK>
# = <UNK> <UNK>
# < <UNK> <UNK> <UNK> <EOS>
#
# > no driver found
# = कोई ड्राइवर नहीं मिला
# < कोई ड्राइवर नहीं मिला <EOS>
#
# > and when the graves are laid open
# = और जबकि क़बें उखेड़ दी जाएँगी
# < और जबकि क़बें उखेड़ दी जाएँगी <EOS>
#
# > that created value in the world .
# = जिसका इस दुनिया में कोई मूल्य हो
# < जिसका इस दुनिया में मान पैदा हो रहा <EOS>
#
# > use graphical smileys
# = आलेखीय स्माइली का प्रयोग करें
# < आलेखीय स्माइली का प्रयोग करें <EOS>
#
# Iter: 41
# Learning Rate: 1
# Time: 2h 47m 31s
# Train Loss: 0.6438319312877009
#
# > a home for the rebellious .
# = सरकशों का ठिकाना है
# < सरकशों के लिए घर देने वाली घर <EOS>
#
# > these trees were planted by them .
# = ये पेड़ उन्होंने लगाए थे
# < इन पेड़ ने ये पेड़ दिये दिए थे <EOS>
#
# > mohammed ali jinnah
# = मुहम्मद अली जिन्ना
# < मोहम्मद अली मोहम्मद था <EOS>
#
# > do not <UNK> with public water pipes .
# = पानी के सार्वजनिक <UNK> के साथ <UNK> नहीं करें
# < पानी के <UNK> के साथ <UNK> <UNK> न करें <EOS>
#
# > a key character of herbaceous species .
# = <UNK> प्रजाति का <UNK> लक्षण
# < <UNK> प्रजाति का महत्वपूर्ण चरित्र <EOS>
#
# > previous important message
# = पूर्ववर्ती महत्वपूर्ण संदेश
# < पूर्ववर्ती महत्वपूर्ण संदेश <EOS>
#
# > which is inspired by nature .
# = जो प्रकृति से प्रेरित है
# < जो <UNK> से प्रेरित हो <EOS>
#
# > the woman was silent for some time .
# = <UNK> कुछ देर तक खामोश रही
# < औरत कुछ देर तक चुप रही <EOS>
#
# > horizontal alignment of the actor within the cell
# = सेल के भीतर कर्ता का क्षैतिज संरेखण
# < सेल के भीतर कर्ता का क्षैतिज संरेखण <EOS>
#
# > soy meal production
# = सोया मील उत्पादन
# < सोया भोजन उत्पादन की उत्पादन <EOS>
#
# Iter: 42
# Learning Rate: 1
# Time: 2h 51m 38s
# ...
# = आधुनिक हिंदी पद्य का इतिहास
# < आधुनिक हिंदी पद्य का इतिहास <EOS>
#
# > the style of hinting
# = हिंटिंग की शैली
# < हिंटिंग की शैली इससे <EOS>
#
# Iter: 62
# Learning Rate: 1
# Time: 4h 13m 10s
# Train Loss: 0.4039435090633947
#
# > remember this password
# = याद रखें यह कूटशब्द
# < याद रखें यह कूटशब्द याद रखें <EOS>
#
# > enable icon in notification area .
# = अधिसूचना क्षेत्र में प्रतीक सक्रिय करें
# < अधिसूचना क्षेत्र में प्रतीक सक्रिय करें <EOS>
#
# > list local address book folders
# = स्थानीय पता पुस्तिका फ़ोल्डरों की सूची दें
# < स्थानीय पता पुस्तिका फ़ोल्डर की सूची दें <EOS>
#
# > moti <UNK> you ought to know .
# = सुन तो
# < <UNK> को तुम जानने की <UNK> करो <EOS>
#
# > symbol viewer configuration page
# = प्रतीक प्रदर्शक कॉन्फ़िगरेशन पृष्ठ
# < प्रतीक प्रदर्शकName कॉन्फ़िगरेशन पृष्ठ भाग <EOS>
#
# > the item has no attendees .
# = इस वस्तु पर कोई उपस्थिति नहीं है
# < इस वस्तु पर कोई उपस्थिति नहीं है <EOS>
#
# > faith in god
# = ईश्वर में विश्वास करना
# < ईश्वर में विश्वास करना <EOS>
#
# > window to desktop
# = विंडो डेस्कटॉप पर
# < विंडो डेस्कटॉप पर <EOS>
#
# > enable file preview
# = फ़ाइल पूर्वावलोकन सक्रिय करें
# < फ़ाइल पूर्वावलोकन सक्रिय करें <EOS>
#
# > amount <UNK> to immovable property
# = <UNK> संपत्ति से मानी या सकने वाली रकम
# < <UNK> संपत्ति से अचल संपत्ति की <UNK> <EOS>
#
# Iter: 63
# Learning Rate: 1
# Time: 4h 17m 12s
# Train Loss: 0.39553267518864066
#
# > correct for light travel time
# = प्रकाश संचरण समय को ध्यान में <UNK>
# < प्रकाश यात्रा समय के लिए <UNK> <EOS>
#
# > reset print range
# = <UNK> सीमा रीसेट करें
# < छपाई सीमा सीमा तक रीसेट करें <EOS>
#
# > nor is your companion distracted .
# = और तुम्हारे साथी मोहम्मद दीवाने नहीं हैं
# < और यह तुम्हारा साथी भी है <EOS>
#
# > equation of this line is .
# = इस रेखा के समीकरण है
# < इस लकीर के समीकरण है <EOS>
#
# > show or hide bookmarks bar
# = पसंद पट्टी छुपाएँ या दिखाएँ
# < पसंद पट्टी छुपाएँ या दिखाएँ <EOS>
#
# > printer not found
# = प्रिंटर पाया नहीं गया
# < मुद्रक नहीं मिला <EOS>
#
# > cannot overwrite existing file s
# = मौजूदा फाइल के ऊपर नहीं लिख सका
# < मौजूदा फाइल के ऊपर लिख नहीं सका <EOS>
#
# > to do the payment the utility bill
# = शुल्क बिल आदि का भुगतान करना
# < शुल्क का भुगतान कर देना करना <EOS>
#
# > services controlled by central government .
# = केन्द्र द्वारा नियन्त्रित सेवाएं
# < केंद्र सरकार द्वारा नियन्त्रित सेवाएं <EOS>
#
# > mouth . minute opening or <UNK>
# = मुख सूक्ष्म छिद्र या रन्ध्र
# < मुख या सूक्ष्म मुख का छिद्र या <EOS>
#
# Iter: 64
# Learning Rate: 1
# Time: 4h 21m 14s
# Train Loss: 0.38736017000789924
#
# > all of those photos become linked together
# = इन सभी तस्वीरों को साथ जोड़ दिया गया है
# < इन तस्वीरों को <UNK> एक साथ जुड़ा गया <EOS>
#
# > distance in kilometers from the current location .
# = से किलोमीटर में दूरी वर्तमान स्थान
# < से किलोमीटर मीटर में दूरी <EOS>
#
# > display the cell
# = सेल प्रदर्शित कीजिए
# < सेल के कक्ष प्रदर्शित करता है <EOS>
#
# > <UNK> is latent form of a virus .
# = <UNK> वायरस का <UNK> रूप होता है
# < <UNK> वायरस का <UNK> रूप होता है <EOS>
#
# > large cardamom product plan
# = बड़ी <UNK> <UNK> योजना
# < बड़ी <UNK> उत्पाद योजना प्लान <EOS>
#
# > select name of the evolution backup file
# = एवोल्यूशन बैकअप फ़ाइल का नाम चुनें
# < एवोल्यूशन बैकअप फ़ाइल का नाम चुनें <EOS>
#
# > default reminder units
# = तयशुदा संसूचक ईकाई
# < तयशुदा संसूचक ईकाई <EOS>
#
# > there hath approached the approaching hour .
# = कयामत क़रीब आ गयी
# < हर घंटे ने प्रश्न <UNK> <EOS>
#
# > these are the package benefits of this policy .
# = इस पॉलिसी की ये <UNK> सुविधाएं हैं
# < इस पॉलिसी की ये पैकेज लाभ है <EOS>
#
# > please only add files with video content
# = कृपया केवल विडियो अंतर्वस्तु वाली फाइलें जोड़ें
# < कृपया केवल विडियो अंतर्वस्तु वाली फाइलें जोड़ें <EOS>
#
# Iter: 65
# Learning Rate: 1
# Time: 4h 25m 16s
# Train Loss: 0.37966685023769503
#
# > you can see a web address
# = आप एक वेब पता देख सकते हैंः
# < आप एक वेब पता देख सकते हैं <EOS>
#
# > show license information
# = लाइसेंस की जानकारी दिखाएँ
# < लाइसेंस की जानकारी दिखाएँ <EOS>
#
# > the name of the property to animate
# = गुण नाम को सजीव करें
# < गुण नाम को सजीव करें <EOS>
#
# > about third party anjuta plugins
# = के बारे में तीसरा
# < के बारे में तीसरा <EOS>
#
# > this investment is beneficial in the long run
# = यह निवेश लंबे समय में लाभकारी है
# < यह निवेश लंबे समय में लाभकारी है <EOS>
#
# > group items by
# = इसके द्वारा समूहीकृत
# < इसके द्वारा समूहीकृत <EOS>
#
# > port number for http requests
# = एचटीटीपी निवेदन के लिए पोर्ट संख्या
# < एचटीटीपी निवेदन के लिए पोर्ट संख्या <EOS>
#
# > funds invested in a business .
# = व्यापार व्यवसाय में लगाई गई धन राशि
# < व्यापार व्यवसाय में निवेश की सुविधा <EOS>
#
# > north sea flood of
# = उत्तरी सागर बाढ़ १९५३
# < उत्तरी सागर बाढ़ १९५३ <EOS>
#
# > reduction of <UNK> production and consumption in .
# = में <UNK> उत्पादन और खपत में की कमी
# < में अधिक उत्पादन और खपत में की कमी <EOS>
#
# Iter: 66
# Learning Rate: 1
# Time: 4h 29m 18s
# Train Loss: 0.3715208936113688
#
# > subhash babu stayed in europe from to .
# = से तक सुभाषबाबू यूरोप में रहे
# < से तक सुभाषबाबू यूरोप यूरोप में रहे <EOS>
#
# > remote desktop client
# = रिमोट डेस्कटॉप <UNK>
# < रिमोट डेस्कटॉप क्लाएंट दूरस्थ <EOS>
#
# > the <UNK> of the doctor was <UNK> .
# = चिकित्सक का बोलना <UNK> था
# < डाक्टर का <UNK> था <EOS>
#
# > refined oil <UNK>
# = परिष्कृत तेल वाष्पीकरण
# < परिष्कृत तेल प्रसार से पूर्व <EOS>
#
# > sanskritum google discussion group about sanskrit
# = संस्कृतम् संस्कृत के बारे में गूगल चर्चा समूह
# < संस्कृत के बारे में गूगल गूगल चर्चा समूह <EOS>
#
# > but when i am back in afghanistan
# = लेकिन जब मैं अफगानिस्तान में वापस आ रहा हूँ
# < लेकिन जब मैं अफगानिस्तान में वापस आ रहा हूँ <EOS>
#
# > something that is related to an <UNK> .
# = क्रिया विशेषण से संबंधित
# < <UNK> या <UNK> से संबंधित <EOS>
#
# > construct the directrix of this conic
# = इस शंकु का <UNK> निर्माण करें
# < इस शंकु का <UNK> निर्माण करें <EOS>
#
# > draw window frames using titlebar colors
# = शीर्षक पट्टी रंगों के उपयोग से विंडो फ्रेम बनाएँ
# < मेन्यू रंगों के उपयोग से विंडो फ्रेम बनाएँ <EOS>
#
# > charles darwin foundation
# = चार्ल्स डार्विन फाउंडेशन
# < चार्ल्स डार्विन फाउंडेशन फाउंडेशन <EOS>
#
# Iter: 67
# Learning Rate: 1
# Time: 4h 33m 21s
# Train Loss: 0.3629969943096431
#
# > turks and caicos islands
# = तुर्क तथा कैकोस आइलैंड
# < तुर्क एवं कैकोस द्वीप समूह <EOS>
#
# > <UNK> temple <UNK>
# = <UNK> का <UNK> मंदिर
# < <UNK> मंदिर <UNK> <UNK> <EOS>
#
# > passive consent for same wrong .
# = किसी गलत कार्य के प्रति अक्रिय सहमति
# < किसी गलत गलत कार्य के प्रति अक्रिय सहमति <EOS>
#
# > enable thumbnailing of pdf documents
# = का थंबनेल सक्षम करें
# < पीडीएफ़ दस्तावेजों का थंबनेल सक्षम करें <EOS>
#
# > save current view
# = वर्तमान दृश्य सहेजें
# < वर्तमान दृश्य सहेजें <EOS>
#
# > on how that machine works .
# = कि यह मशीन कैसे काम करती है
# < यह मशीन कि कैसे काम कर रहा था <EOS>
#
# > cannot start the game s
# = खेल आरंभ नहीं कर सका
# < खेल आरंभ नहीं कर सका <EOS>
#
# > because they re seeing the world
# = क्योंकि वे इस दुनिया को
# < क्योंकि वे दुनिया को याद करते है <EOS>
#
# > bottom of page
# = कोई नाम नहीं
# < पृष्ठ का तल <EOS>
#
# > embedded hex editor
# = अंतर्निर्मित <UNK> संपादक
# < <UNK> <UNK> संपादक <EOS>
#
# Iter: 68
# Learning Rate: 1
# Time: 4h 37m 24s
# Train Loss: 0.3568483985878481
#
# > reverse the list order
# = अनुक्रम सूची उलटें
# < अनुक्रम सूची उलटें <EOS>
#
# > a list of public servants .
# = <UNK> की सूची
# < सार्वजनिक गणराज्य की सूची <EOS>
#
# > the blue line is an indication
# = ब्लू लाइन एक संकेत है
# < ब्लू लाइन संकेत एक संकेत है <EOS>
#
# > a photo taken from an aircraft .
# = वायुयान से लिया गया चित्र
# < वायुयान से लिया गया <UNK> <EOS>
#
# > message is not junk
# = संदेश कचरा डाक नहीं है
# < संदेश कचरा डाक नहीं है <EOS>
#
# > configure web cache settings
# = वेब कैश विन्यास कॉन्फ़िगर करेंName
# < वेब कैश विन्यास विन्यास कॉन्फ़िगर करेंName <EOS>
#
# > unable to launch external application .
# = बाहरी अनुप्रयोग लॉन्च करने में असमर्थ
# < बाहरी अनुप्रयोग लॉन्च करने में असमर्थ <EOS>
#
# > <UNK> behind the mirror image of lake .
# = प्रतिबिम्बित झील के पीछे पैदल पथ
# < प्रतिबिम्बित झील के पीछे पैदल पथ <EOS>
#
# > infestation with fly maggots
# = <UNK> से उत्पन्न कष्ट या रोग
# < <UNK> वाली <UNK> के साथ संगत <UNK> <EOS>
#
# > swap primary mouse button
# = प्राथमिक माउस बटन स्वैप करें
# < प्राथमिक माउस बटन बटन स्वैप रूप से <EOS>
#
# Iter: 69
# Learning Rate: 1
# Time: 4h 41m 28s
# Train Loss: 0.3488307194832417
#
# > after him bharat was crowned king .
# = उसके बाद भरत राजा हुए
# < बाद में उनके बाद यह <UNK> बना हुआ <EOS>
#
# > error no player to destroy
# = त्रुटिः खत्म करने के लिए कोई खिलाड़ी नहीं
# < त्रुटिः खत्म करने हेतु खिलाड़ी कोई खिलाड़ी नहीं <EOS>
#
# > write the total number of future entries after <UNK>
# = आगत प्रविष्टियों की गणना कर कुल संख्या लिखें
# < <UNK> के बाद की कुल संख्या <UNK> <EOS>
#
# > what do you like to do ?
# = आपको क्या करना अच्छा लगता है
# < <UNK> क्या करना अच्छा काम पसंद करता है <EOS>
#
# > what is the terminal cost of this project ?
# = इस योजना की जॉब लागत क्या है
# < इस योजना की <UNK> लागत क्या है <EOS>
#
# > folder list is not available in offline mode
# = ऑफ़लाइन अवस्था में फ़ोल्डर सूची उपलब्ध नहीं
# < ऑफ़लाइन अवस्था में फ़ोल्डर सूची उपलब्ध नहीं <EOS>
#
# > and because you cannot see the <UNK>
# = क्युकि आप कंपन नहीं देख सकते
# < आप देख सकते है कि <UNK> नहीं <EOS>
#
# > flowcharting paper tape <UNK>
# = <UNK> कागज टेप <UNK>
# < <UNK> कागज टेप टेप <UNK> <EOS>
#
# > a drink containing alcoholic contents .
# = नशा देने वाली मदिरा
# < मदिरा सामग्रियों को एक ले <UNK> <EOS>
#
# > the true god of mankind
# = लोगों के माबूद की
# < लोगों के माबूद की <EOS>
#
# Iter: 70
# Learning Rate: 1
# Time: 4h 45m 32s
# Train Loss: 0.3423357399325228
#
# > the storm lasted fourteen to sixteen hours .
# = तूफान चौदह से सोलह घंटे चला
# < चक्र को <UNK> घंटे तक चला जाता है <EOS>
#
# > gadu gadu work id
# = गाडू गाडू कार्य
# < गाडू गाडू कार्य <EOS>
#
# > one times five is five .
# = गुना है
# < गुना है <EOS>
#
# > sanskrit software and its machinery
# = संस्कृत साफ्टवेयर एवं उपकरणः
# < संस्कृत साफ्टवेयर और उसके मशीनरी <EOS>
#
# > the number of anchors associated with the atkhyperlink object
# = एटीके हायपरलिंक वस्तु के साथ सम्बद्ध लंगर की संख्या
# < एटीके हायपरलिंक वस्तु के साथ सम्बद्ध लंगर की संख्या <EOS>
#
# > accounting finance system
# = लेखांकन वित्त तंत्र
# < लेखांकन वित्त तंत्र तंत्र <EOS>
#
# > automatically synchroni ze account locally
# = स्वचालित तुल्यकालन खाता स्थानीय रूप से
# < स्वतः तुल्यकालन खाता स्थानीय रूप से स्वतः करें <EOS>
#
# > <UNK> national park
# = पन्ना नेशनल पार्क
# < <UNK> राष्ट्रीय उद्यान <EOS>
#
# > <UNK> for high dynamic range imaging
# = <UNK> डायनॉमिक रेंज इमेजिंग के लिए
# < <UNK> डायनॉमिक रेंज इमेजिंग के लिए <EOS>
#
# > it turns out that corporate west africa
# = ऐसा समझ आता है कि <UNK> अफ्रीका
# < ऐसा समझ आता है कि <UNK> अफ्रीका <EOS>
#
# Iter: 71
# Learning Rate: 1
# Time: 4h 49m 35s
# Train Loss: 0.3343939281692124
#
# > central board of secondary education
# = केन्द्रीय माध्यमिक शिक्षा मण्डल
# < केंद्रीय माध्यमिक शिक्षा बोर्ड द्वारा बोर्ड <EOS>
#
# > how the police can help you
# = आपको पुलिस से मदद कैसे मिल सकती है
# < आपको ये कैसे मदद कर सकते हैं <EOS>
#
# > thus do we deal with the <UNK> !
# = अपराधियों के साथ हम ऐसा ही करते है
# < अपराधियों के साथ हम ऐसा ही करते है <EOS>
#
# > when the value assessed is too high .
# = जब <UNK> मूल्य बहुत ज्यादा हो
# < जब का मूल्य बहुत ज्यादा हो <EOS>
#
# > create automatic playlist
# = स्वतः प्लेलिस्ट बनाएँ
# < बनाने हेतु स्वतः प्लेलिस्ट बनाएँ <EOS>
#
# > build acumen fund about six years ago .
# = <UNK> <UNK> <UNK> करीब छः साल पहले
# < <UNK> वर्ष करीब छः साल पहले बनाएं <EOS>
#
# > as if they were frightened donkeys .
# = गोया वह वहशी गधे हैं
# < मानो वे बिदके हुए जंगली गधे है <EOS>
#
# > show archive properties
# = अभिलेख गुणों को दिखाएँ
# < अभिलेख गुणों को दिखाएँ <EOS>
#
# > x minus the second root .
# = ब दूसरा हल को गुणा <UNK> तो
# < शून्य दूसरे वर्ग के <EOS>
#
# > a check box with text label
# = पाठ लेबल युक्त चेक बक्सा
# < पाठ लेबल युक्त चेक बक्सा <EOS>
#
# Iter: 72
# Learning Rate: 1
# Time: 4h 53m 37s
# Train Loss: 0.32910662399626334
#
# > but between those high <UNK>
# = लेकिन इन बेहतरीन लम्हों के बीच
# < लेकिन इन उच्च लम्हों के बीच <EOS>
#
# > the lecturer <UNK> the class test .
# = व्याख्याता ने कक्षा परिक्षण को <UNK> किया
# < यह <UNK> प्लेयर क्लास परीक्षा में थी <EOS>
#
# > and then we shall save our country .
# = और फिर हम अपने देश को <UNK>
# < और फिर हम अपने देश को <UNK> <EOS>
#
# > create a new memo list
# = नई ज्ञापन सूची बनाएँ
# < नई ज्ञापन सूची बनाएँ <EOS>
#
# > the expansion of the programme <UNK>
# = कार्यक्रम के विस्तार के माध्यम से
# < कार्यक्रम को <UNK> करने के लिए विस्तार <EOS>
#
# > and laugh and not weep
# = और हँसते हो और रोते नहीं
# < और रोते नहीं हो <EOS>
#
# > the state of being of service .
# = सेवा की स्थिति
# < सेवा की स्थिति का राज्य <EOS>
#
# > the roman empire has been defeated
# = रूमी निकटवर्ती क्षेत्र में पराभूत हो गए हैं
# < रूमी में काफी हार गए <EOS>
#
# > simulation of image to disc burning
# = छवि की डिस्क बर्निंग का सिमुलेशन
# < छवि की डिस्क बर्निंग डिस्क का सिमुलेशन <EOS>
#
# > the default plugin for junk hook
# = कचरा डाक हुक के लिए तयशुदा प्लगिन
# < कचरा डाक हुक के लिए तयशुदा प्लगिन <EOS>
#
# Iter: 73
# Learning Rate: 1
# Time: 4h 57m 40s
# Train Loss: 0.3223279916891276
#
# > please only add files with video content
# = कृपया केवल विडियो अंतर्वस्तु वाली फाइलें जोड़ें
# < कृपया केवल विडियो अंतर्वस्तु वाली फाइलें जोड़ें <EOS>
#
# > lalit kala akademi
# = ललित कला अकादमी
# < ललित कला अकादमी <EOS>
#
# > something that is supplementary to what already exist .
# = मौजूद वस्तु के अतिरिक्त उपलब्ध कराना
# < मौजूद से कार्य <EOS>
#
# > to make these stories work .
# = इन कहानियों का काम बनाने के लिए
# < इन कहानियों का प्रयत्न करने के लिये <EOS>
#
# > refresh the folder list
# = फ़ोल्डर सूची ताज़ा करें
# < फ़ोल्डर सूची में ताज़ा किया जा <EOS>
#
# > sometimes i do
# = कभी कभी लगता है
# < कभी कभी चाहती हो नहीं <EOS>
#
# > static mobile pressure vessels rules
# = स्थिर तथा गतिशील <UNK> नियम
# < निर्धारित मोबाइल <UNK> नियम <EOS>
#
# > <UNK> products based on aluminum
# = एल्युमिनियम पर आधारित <UNK> <UNK>
# < लगातार आधारित <UNK> पर आधारित होते हैं <EOS>
#
# > server response contained incomplete authorization data
# = सर्वर अनुक्रिया के पास अपूर्ण प्राधिकार आंकड़ा है
# < सर्वर अनुक्रिया के पास अपूर्ण प्राधिकार आंकड़ा है <EOS>
#
# > playing tennis is easy for me .
# = मेरे लिए टेनिस खेलना बहुत आसान है
# < मेरे लिए टेनिस खेलना बहुत आसान है <EOS>
#
# Iter: 74
# Learning Rate: 1
# Time: 5h 1m 42s
# Train Loss: 0.3162421424062407
#
# > widget factory base
# = विजेट <UNK> <UNK>
# < विजेट फैक्टरी आधार आधार <EOS>
#
# > name is the same as the original one
# = नाम मूल नाम के समान है
# < नाम मूल रूप के बराबर है मूल में <EOS>
#
# > something that leads to awe .
# = विस्मय से संबंधित
# < जिसे से <UNK> प्राप्त हो जाता है <EOS>
#
# > charles francis <UNK>
# = चार्ल्स <UNK> <UNK>
# < चार्ल्स <UNK> <UNK> <UNK> <EOS>
#
# > bhandarkar oriental research institute
# = <UNK> <UNK> शोध संस्थान
# < <UNK> <UNK> रिसर्च <UNK> <UNK> संस्थान <EOS>
#
# > subscribe to my notifications
# = मेरी सूचना की सदस्यता लें
# < मेरे <UNK> सूचनाओं की पुष्टि की निगरानी करें <EOS>
#
# > conflict in afghanistan
# = अफ़ग़ानिस्तान का गृहयुद्ध
# < अफ़ग़ानिस्तान में विरोधाभास <EOS>
#
# > use spamassassin daemon and client .
# = स्पैमएस्सेसिन डेमन और ग्राहक का प्रयोग करें
# < स्पैमएस्सेसिन डेमन और ग्राहक का प्रयोग करें <EOS>
#
# > default charset in which to compose messages .
# = तयशुदा चारसेट जिसमें संदेश लिखना है
# < तयशुदा चारसेट जिसमें संदेश लिखना है <EOS>
#
# > her face was wet with tears .
# = <UNK> से चेहरा <UNK> गया था
# < <UNK> का <UNK> खड़ा था <EOS>
#
# Iter: 75
# Learning Rate: 1
# Time: 5h 5m 46s
# Train Loss: 0.3094070526522146
#
# > maintaining <UNK> of ies officers
# = आईईएस अधिकारियों की वार्षिक कार्य निष्पादन रिपोर्ट रखना
# < आईईएस अधिकारियों की वार्षिक प्रक्रिया तैयार करना <EOS>
#
# > the former published it in .
# = <UNK> ने उसे मे <UNK>
# < <UNK> ने उसे में देखा <EOS>
#
# > contact scoda for more details .
# = अधिक जानकारी के लिए <UNK> से सम्पर्क करें
# < अधिक जानकारी के लिए से संपर्क करें <EOS>
#
# > <UNK> wants to become an anthropologist .
# = <UNK> <UNK> बनना चाहता है
# < <UNK> को <UNK> बनना चाहता है <EOS>
#
# > enter new password for certificate database
# = प्रमाणपत्र डाटाबेस के लिए नया कूटशब्द दाखिल करें
# < प्रमाणपत्र डाटाबेस के लिए नया कूटशब्द दाखिल करें <EOS>
#
# > it was a profoundly true remark .
# = यह कथन बहुत ही सटीक था
# < यह <UNK> सही का <UNK> था <EOS>
#
# > this task has been deleted .
# = यह कार्य मिटायी जा चुकी है
# < यह कार्य मिटायी जा चुकी है <EOS>
#
# > so someone tells us the story about <UNK>
# = तो कोई हमे <UNK> की कहानी बताता है
# < तो कोई हमे <UNK> की कहानी बताता है <EOS>
#
# > and the rabbits that are bad at it
# = और वो खरगोश जो अच्छे नहीं होते हैं वो
# < और वो खरगोश जो अच्छे नहीं होते हैं वो <EOS>
#
# > islamic consultative assembly
# = इस्लामी <UNK> सभा
# < इस्लामी <UNK> सभा <EOS>

# %%
pwd
# Out:
# '/content/drive/My Drive/Language-Translation-datasets/IITBombay/prunedCorpus'

# %%
train_pairs

# %%
ls

# %%
from google.colab import files
files.download('testdata.orig_trim.10_vocab.20000_directions.2_layers.2_hidden.440_dropout.0.2_learningrate.1_batch.32_epochs.100.txt')

# %%
outside_sent = "बाहर बारिश होने से पहले वह सेब खाने जा रहा है"
outside_sent = normalizeString(outside_sent)
evaluate(encoder, decoder, outside_sent, cutoff_length=10)
# Out:
# 'they are also known as rolls . <EOS>'

# %%
demh = ['प्रायः हम इस भंडार को लौकिक विषयों पर और पत्नी , पुत्र मित्र आदि सगे संबंधियों पर प्रवर्तित कर देते हैं । \n', 'मुझे जनता हूँ की मैं इस वीडियो में किसी भी समय\n', 'वेब ब्राउज़र मदद दिखाएँ\n', 'और उसने अपनी मेहरबानी से तुम्हारे वास्ते रात और दिन को बनाया ताकि तुम रात में आराम करो और दिन में उसके फज़ल व करम की तलाश करो और ताकि तुम लोग शुक्र करो\n', 'एब्सकार्बिक अम्ल कुपोषण की कमी के कारण द्वारा होने वाली बीमारी जो आमतौर से लोगो में होता है जिसके कारण गोलाकार धब्बे , पट्टियों या जांघों , बांह और धड़ पर चकत्ते । \n', 'प्रथम मंदिर तीसरी शताब्दी बी . सी . में सम्राट अशोक द्वारा निर्मित कराया गया था और वर्तमान मंदिर पांचवीं या छठवीं शताब्दी में बनाए गए । \n', 'तो अगर तुम्हें कोई दाँव करना हो तो आओ चल चुको\n', 'छाती में तेज दर्द अथवा सांस लेने में तकलीफ हो\n', 'इस प्रकार के सभी लिंक के लिए मेरा चयन याद रखें . \n', 'इस प्रयास पर और अधिक जोर देने की आवश्यकता है । \n']

# %%
def hindi_normalizeString(s):
  def hindi_processing(word):
      correct = ''
        # print(char)
      if ( u'\u0900' <= word <= u'\u097f') or word==" ":
        correct=correct+word
      return correct

  # with codecs.open('letter.tx', encoding='utf-8') as f:
 
  
  temp = ''
  s = s.replace('।', '')
  for i in s.split():
      correct = hindi_processing(i)
      temp = temp +' ' + correct
      temp = ' '.join(temp.split())
  return temp

check = []
for i in demh:
  check.append(hindi_normalizeString(i))

# %%
check
# Out:
# ['प्रायः हम इस भंडार को लौकिक विषयों पर और पत्नी पुत्र मित्र आदि सगे संबंधियों पर प्रवर्तित कर देते हैं',
#  'मुझे जनता हूँ की मैं इस वीडियो में किसी भी समय',
#  'वेब ब्राउज़र मदद दिखाएँ',
#  'और उसने अपनी मेहरबानी से तुम्हारे वास्ते रात और दिन को बनाया ताकि तुम रात में आराम करो और दिन में उसके फज़ल व करम की तलाश करो और ताकि तुम लोग शुक्र करो',
#  'एब्सकार्बिक अम्ल कुपोषण की कमी के कारण द्वारा होने वाली बीमारी जो आमतौर से लोगो में होता है जिसके कारण गोलाकार धब्बे पट्टियों या जांघों बांह और धड़ पर चकत्ते',
#  'प्रथम मंदिर तीसरी शताब्दी बी सी में सम्राट अशोक द्वारा निर्मित कराया गया था और वर्तमान मंदिर पांचवीं या छठवीं शताब्दी में बनाए गए',
#  'तो अगर तुम्हें कोई दाँव करना हो तो आओ चल चुको',
#  'छाती में तेज दर्द अथवा सांस लेने में तकलीफ हो',
#  'इस प्रकार के सभी लिंक के लिए मेरा चयन याद रखें',
#  'इस प्रयास पर और अधिक जोर देने की आवश्यकता है']
